# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dask.dataframe as ddf
from pandas import Series, DataFrame
# %matplotlib inline

# %%
import seaborn as sn
import plotly.express as px

# %%
ur_files = ddf.read_csv('EnvironmentSuicide/Environment_Suicide_2020.csv', dtype = {'fips': str})
climate_2020 = ur_files.compute()
climate_2020 = climate_2020.loc[:, ~climate_2020.columns.str.contains('^Unnamed')]
climate_2020.head()
# Out:
#     fips   elevation  mean_temp  visibility  wind_speed  precipitation  \
# 0  01001   75.264706  65.805031    9.316751    4.196802       0.190582
# 1  01003   12.427907  70.433061    9.238159    3.963549       0.080860
# 2  01005   94.311111  61.456968    9.185657    3.097790       0.096706
# 3  01007  162.637500  64.168787    9.348708    4.395276       0.156465
# 4  01009  243.931250  61.962995    9.399952    4.475978       0.133215
#
#          fog        rain      snow  hail    thunder  Relative_Humidity  \
# 0  30.117647  155.000000  0.705882   0.0  45.529412          72.441193
# 1  13.488372   34.906977  0.000000   0.0  11.488372          78.214097
# 2  16.000000   39.888889  0.000000   0.0   8.888889          72.878378
# 3  24.250000  109.500000  0.250000   0.0  36.250000          73.841053
# 4  11.312500   74.125000  0.750000   0.0  22.187500          69.557608
#
#    Heat_Index  rurality  SuicideDeathRate
# 0   66.733307       3.0         10.255687
# 1   69.488485       4.0         13.520173
# 2   59.999685       6.0         17.171214
# 3   63.784285       2.0          8.501098
# 4   62.180748       2.0         14.035878

# %%
climate_2020 = climate_2020[['fips', 'elevation', 'mean_temp', 'visibility', 'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail', 'thunder', 'Relative_Humidity', 'Heat_Index','rurality','SuicideDeathRate']]

# %%
climate_2020 = climate_2020.dropna()

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
X = climate_2020.iloc[:, 1:-1].values
y = climate_2020.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.22745615, 0.08371849, 0.06894317, 0.06946451, 0.05000072,
#        0.04648755, 0.06402488, 0.05989062, 0.00527023, 0.05180558,
#        0.07637027, 0.13991546, 0.05665238])

# %%
len(rf.feature_importances_)
# Out:
# 13

# %%
columns = climate_2020.columns

# %%
columns = columns[1:-1]
columns = columns.tolist()
columns
# Out:
# ['elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'Relative_Humidity',
#  'Heat_Index',
#  'rurality']

# %%
len(columns)
# Out:
# 13

# %%
plt.barh(columns, rf.feature_importances_)
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
sorted_idx
# Out:
# array([ 8,  5,  4,  9, 12,  7,  6,  2,  3, 10,  1, 11,  0])

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
rf.feature_importances_[sorted_idx]
# Out:
# array([0.00527023, 0.04648755, 0.05000072, 0.05180558, 0.05665238,
#        0.05989062, 0.06402488, 0.06894317, 0.06946451, 0.07637027,
#        0.08371849, 0.13991546, 0.22745615])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
def correlation_matrix(df):
    """
    A function to calculate and plot
    correlation matrix of a DataFrame.
    """
    # Create the matrix
    matrix = df.corr()
    
    # Create cmap
    cmap = sn.diverging_palette(250, 15, s=75, l=40,
                             n=9, center="light", as_cmap=True)
    # Create a mask
    mask = np.triu(np.ones_like(matrix, dtype=bool))
    
    # Make figsize bigger
    fig, ax = plt.subplots(figsize=(16,12))
    
    # Plot the matrix
    _ = sn.heatmap(matrix, mask=mask, center=0, annot=True,
             fmt='.2f', square=True, cmap=cmap, ax=ax)

# %%
correlation_matrix(climate_2020)

# %% [markdown]
# ## Find the economic feature importances

# %%
ur_files = ddf.read_csv('SocialEconomicSuicide/Social_Economic_Suicide_2020.csv', dtype = {'fips': str, 'per_capita_income': float})
social_2020 = ur_files.compute()
social_2020 = social_2020.loc[:, ~social_2020.columns.str.contains('^Unnamed')]
social_2020.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  01001            29804.0               0.152118
# 1  01003            33751.0               0.091737
# 2  01005            20074.0               0.285999
# 3  01007            22626.0               0.180981
# 4  01009            25457.0               0.137361
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.116403              0.166688            0.054131
# 1                       0.100390              0.108923            0.031256
# 2                       0.261505              0.276632            0.111457
# 3                       0.203478              0.319448            0.066263
# 4                       0.184483              0.224651            0.050790
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.189026              0.015724                    0.038739
# 1                0.205768              0.015230                    0.167139
# 2                0.307314              0.037546                    0.014100
# 3                0.289358              0.012536                    0.024683
# 4                0.247931              0.018156                    0.006843
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.152591                           0.035818
# 1                  0.204848                           0.043809
# 2                  0.190881                           0.067907
# 3                  0.164298                           0.021306
# 4                  0.179759                           0.067410
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.236219            0.260231          0.647028
# 1                    0.215279            0.171030          0.470731
# 2                    0.208663            0.547191          0.625344
# 3                    0.204881            0.255833          0.486243
# 4                    0.231530            0.133149          0.525806
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.010388
# 1                                     0.013533
# 2                                     0.116279
# 3                                     0.074059
# 4                                     0.009765
#
#    percent_single_parent_households_CDC              county  SuicideDeathRate
# 0                              0.276040  Autauga County, AL         10.255687
# 1                              0.183638  Baldwin County, AL         13.520173
# 2                              0.540406  Barbour County, AL         17.171214
# 3                              0.367041     Bibb County, AL          8.501098
# 4                              0.225584   Blount County, AL         14.035878

# %%
social_2020['SuicideDeathRate'].isna().sum()
# Out:
# 123

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
social_2020 = social_2020.dropna(how = 'any')

# %%
social_2020.shape
# Out:
# (3098, 18)

# %%
X = social_2020.iloc[:, 1:-2].values
y = social_2020.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.06159325, 0.04017303, 0.09748977, 0.18159952, 0.05472148,
#        0.04222421, 0.05580644, 0.05325451, 0.06767212, 0.05396065,
#        0.04707006, 0.06077778, 0.09662196, 0.0422651 , 0.04477013])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = social_2020.columns
columns = columns[1:-2]
columns = columns.tolist()
columns
# Out:
# ['per_capita_income',
#  'percent_below_poverty',
#  'percent_no_highschool_diploma',
#  'percent_mobile_homes',
#  'percent_no_vehicle',
#  'percent_unemployed_CDC',
#  'percent_overcrowding',
#  'percent_multi_unit_housing',
#  'percent_age_65_and_older',
#  'percent_limited_english_abilities',
#  'percent_age_17_and_younger',
#  'percent_minorities',
#  'percent_disabled',
#  'percent_institutionalized_in_group_quarters',
#  'percent_single_parent_households_CDC']

# %%
social_2020.shape
# Out:
# (3098, 18)

# %%
climate_2020.shape
# Out:
# (2938, 15)

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
correlation_matrix(social_2020)

# %% [markdown]
# ## find the rank of importances of all factors

# %%
df_total = social_2020.merge(climate_2020, on = ['fips', 'SuicideDeathRate'], how = 'left')
df_total = df_total.dropna(how = 'any')
df_total.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  01001            29804.0               0.152118
# 1  01003            33751.0               0.091737
# 2  01005            20074.0               0.285999
# 3  01007            22626.0               0.180981
# 4  01009            25457.0               0.137361
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.116403              0.166688            0.054131
# 1                       0.100390              0.108923            0.031256
# 2                       0.261505              0.276632            0.111457
# 3                       0.203478              0.319448            0.066263
# 4                       0.184483              0.224651            0.050790
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.189026              0.015724                    0.038739
# 1                0.205768              0.015230                    0.167139
# 2                0.307314              0.037546                    0.014100
# 3                0.289358              0.012536                    0.024683
# 4                0.247931              0.018156                    0.006843
#
#    percent_age_65_and_older  ...  wind_speed  precipitation        fog  \
# 0                  0.152591  ...    4.196802       0.190582  30.117647
# 1                  0.204848  ...    3.963549       0.080860  13.488372
# 2                  0.190881  ...    3.097790       0.096706  16.000000
# 3                  0.164298  ...    4.395276       0.156465  24.250000
# 4                  0.179759  ...    4.475978       0.133215  11.312500
#
#          rain      snow  hail    thunder  Relative_Humidity  Heat_Index  \
# 0  155.000000  0.705882   0.0  45.529412          72.441193   66.733307
# 1   34.906977  0.000000   0.0  11.488372          78.214097   69.488485
# 2   39.888889  0.000000   0.0   8.888889          72.878378   59.999685
# 3  109.500000  0.250000   0.0  36.250000          73.841053   63.784285
# 4   74.125000  0.750000   0.0  22.187500          69.557608   62.180748
#
#    rurality
# 0       3.0
# 1       4.0
# 2       6.0
# 3       2.0
# 4       2.0
#
# [5 rows x 31 columns]

# %%
col = df_total.columns.values

# %%
col
# Out:
# array(['fips', 'per_capita_income', 'percent_below_poverty',
#        'percent_no_highschool_diploma', 'percent_mobile_homes',
#        'percent_no_vehicle', 'percent_unemployed_CDC',
#        'percent_overcrowding', 'percent_multi_unit_housing',
#        'percent_age_65_and_older', 'percent_limited_english_abilities',
#        'percent_age_17_and_younger', 'percent_minorities',
#        'percent_disabled', 'percent_institutionalized_in_group_quarters',
#        'percent_single_parent_households_CDC', 'county',
#        'SuicideDeathRate', 'elevation', 'mean_temp', 'visibility',
#        'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail',
#        'thunder', 'Relative_Humidity', 'Heat_Index', 'rurality'],
#       dtype=object)

# %%
new_col = ['fips', 'county', 'percent_below_poverty',
       'per_capita_income', 'percent_unemployed_CDC',
       'percent_no_highschool_diploma', 'percent_age_65_and_older',
       'percent_age_17_and_younger', 'percent_disabled',
       'percent_single_parent_households_CDC', 'percent_minorities',
       'percent_limited_english_abilities', 'percent_multi_unit_housing',
       'percent_mobile_homes', 'percent_overcrowding',
       'percent_no_vehicle',
       'percent_institutionalized_in_group_quarters', 
       'elevation', 'mean_temp', 'visibility',
       'wind_speed', 'precipitation', 'Relative_Humidity', 'Heat_Index',
       'fog', 'rain', 'snow', 'hail', 'thunder','rurality','SuicideDeathRate']

# %%
df_total = df_total[new_col]

# %%
df_total.shape
# Out:
# (2938, 31)

# %%
df_total.head()
# Out:
#     fips              county  percent_below_poverty  per_capita_income  \
# 0  01001  Autauga County, AL               0.152118            29804.0
# 1  01003  Baldwin County, AL               0.091737            33751.0
# 2  01005  Barbour County, AL               0.285999            20074.0
# 3  01007     Bibb County, AL               0.180981            22626.0
# 4  01009   Blount County, AL               0.137361            25457.0
#
#    percent_unemployed_CDC  percent_no_highschool_diploma  \
# 0                0.189026                       0.116403
# 1                0.205768                       0.100390
# 2                0.307314                       0.261505
# 3                0.289358                       0.203478
# 4                0.247931                       0.184483
#
#    percent_age_65_and_older  percent_age_17_and_younger  percent_disabled  \
# 0                  0.152591                    0.236219          0.647028
# 1                  0.204848                    0.215279          0.470731
# 2                  0.190881                    0.208663          0.625344
# 3                  0.164298                    0.204881          0.486243
# 4                  0.179759                    0.231530          0.525806
#
#    percent_single_parent_households_CDC  ...  precipitation  \
# 0                              0.276040  ...       0.190582
# 1                              0.183638  ...       0.080860
# 2                              0.540406  ...       0.096706
# 3                              0.367041  ...       0.156465
# 4                              0.225584  ...       0.133215
#
#    Relative_Humidity  Heat_Index        fog        rain      snow  hail  \
# 0          72.441193   66.733307  30.117647  155.000000  0.705882   0.0
# 1          78.214097   69.488485  13.488372   34.906977  0.000000   0.0
# 2          72.878378   59.999685  16.000000   39.888889  0.000000   0.0
# 3          73.841053   63.784285  24.250000  109.500000  0.250000   0.0
# 4          69.557608   62.180748  11.312500   74.125000  0.750000   0.0
#
#      thunder  rurality  SuicideDeathRate
# 0  45.529412       3.0         10.255687
# 1  11.488372       4.0         13.520173
# 2   8.888889       6.0         17.171214
# 3  36.250000       2.0          8.501098
# 4  22.187500       2.0         14.035878
#
# [5 rows x 31 columns]

# %%
plt.rcParams.update({'figure.figsize': (20.0, 12.0)})
plt.rcParams.update({'font.size': 14})
X = df_total.iloc[:, 2:-1].values
y = df_total.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.01581794, 0.02597226, 0.02171016, 0.02043047, 0.0510469 ,
#        0.02070018, 0.03801952, 0.0143937 , 0.02876258, 0.04214031,
#        0.01642112, 0.1423227 , 0.02464877, 0.01473586, 0.01549671,
#        0.15374145, 0.04359078, 0.03392159, 0.03510973, 0.02267405,
#        0.02894239, 0.05026469, 0.02175312, 0.0329777 , 0.03513588,
#        0.01006135, 0.03282323, 0.00638486])

# %%
len(rf.feature_importances_)
# Out:
# 28

# %%
columns = df_total.columns
columns = columns[2:-1]
columns = columns.tolist()
columns
# Out:
# ['percent_below_poverty',
#  'per_capita_income',
#  'percent_unemployed_CDC',
#  'percent_no_highschool_diploma',
#  'percent_age_65_and_older',
#  'percent_age_17_and_younger',
#  'percent_disabled',
#  'percent_single_parent_households_CDC',
#  'percent_minorities',
#  'percent_limited_english_abilities',
#  'percent_multi_unit_housing',
#  'percent_mobile_homes',
#  'percent_overcrowding',
#  'percent_no_vehicle',
#  'percent_institutionalized_in_group_quarters',
#  'elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'Relative_Humidity',
#  'Heat_Index',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'rurality']

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %% [markdown]
# ## SHAP

# %%
import xgboost
import shap

# %%
X = climate_2020.iloc[:, 1:-1]
y = climate_2020.iloc[:, -1].array

# %%
X
# Out:
#         elevation  mean_temp  visibility  wind_speed  precipitation  \
# 0       75.264706  65.805031    9.316751    4.196802       0.190582
# 1       12.427907  70.433061    9.238159    3.963549       0.080860
# 2       94.311111  61.456968    9.185657    3.097790       0.096706
# 3      162.637500  64.168787    9.348708    4.395276       0.156465
# 4      243.931250  61.962995    9.399952    4.475978       0.133215
# ...           ...        ...         ...         ...            ...
# 3137  2148.033333  36.318033    9.558925    6.144536       0.002140
# 3138  2055.000000  44.184973    9.704372   10.570492       0.008767
# 3139  1960.585714  37.678337    9.054098    6.805191       0.046206
# 3140  2190.740000  42.571731    9.472776    9.053288       0.008787
# 3141  1271.600000  45.989344    9.676776    5.222951       0.010109
#
#             fog        rain       snow  hail    thunder  Relative_Humidity  \
# 0     30.117647  155.000000   0.705882   0.0  45.529412          72.441193
# 1     13.488372   34.906977   0.000000   0.0  11.488372          78.214097
# 2     16.000000   39.888889   0.000000   0.0   8.888889          72.878378
# 3     24.250000  109.500000   0.250000   0.0  36.250000          73.841053
# 4     11.312500   74.125000   0.750000   0.0  22.187500          69.557608
# ...         ...         ...        ...   ...        ...                ...
# 3137  26.333333   59.000000  79.000000   0.0  14.666667          57.355772
# 3138  25.000000   51.000000  64.000000   0.0  12.000000          47.900495
# 3139  31.428571   65.714286  93.571429   0.0   9.285714          61.219379
# 3140  46.200000   37.800000  94.800000   0.0   4.000000          49.138534
# 3141  17.000000   44.000000  46.000000   0.0  11.000000          52.224879
#
#       Heat_Index  rurality
# 0      66.733307       3.0
# 1      69.488485       4.0
# 2      59.999685       6.0
# 3      63.784285       2.0
# 4      62.180748       2.0
# ...          ...       ...
# 3137   32.345557       6.0
# 3138   40.554793       5.0
# 3139   34.502038       5.0
# 3140   38.837652       5.0
# 3141   42.733917       6.0
#
# [2938 rows x 13 columns]

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %% [markdown]
# #### The above explanation shows features each contributing to push the model output from the base value (the average model output over the training dataset we passed) to the model output. Features pushing the prediction higher are shown in red, those pushing the prediction lower are in blue.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"elevation"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"rurality"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:,"elevation"],shap_values[:,"rurality"], xmin=500)

# %% [markdown]
# ### scatter plot will pick the best feature to color by automatically

# %% [markdown]
# ### social economic factors

# %%
social_2020.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  01001            29804.0               0.152118
# 1  01003            33751.0               0.091737
# 2  01005            20074.0               0.285999
# 3  01007            22626.0               0.180981
# 4  01009            25457.0               0.137361
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.116403              0.166688            0.054131
# 1                       0.100390              0.108923            0.031256
# 2                       0.261505              0.276632            0.111457
# 3                       0.203478              0.319448            0.066263
# 4                       0.184483              0.224651            0.050790
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.189026              0.015724                    0.038739
# 1                0.205768              0.015230                    0.167139
# 2                0.307314              0.037546                    0.014100
# 3                0.289358              0.012536                    0.024683
# 4                0.247931              0.018156                    0.006843
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.152591                           0.035818
# 1                  0.204848                           0.043809
# 2                  0.190881                           0.067907
# 3                  0.164298                           0.021306
# 4                  0.179759                           0.067410
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.236219            0.260231          0.647028
# 1                    0.215279            0.171030          0.470731
# 2                    0.208663            0.547191          0.625344
# 3                    0.204881            0.255833          0.486243
# 4                    0.231530            0.133149          0.525806
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.010388
# 1                                     0.013533
# 2                                     0.116279
# 3                                     0.074059
# 4                                     0.009765
#
#    percent_single_parent_households_CDC              county  SuicideDeathRate
# 0                              0.276040  Autauga County, AL         10.255687
# 1                              0.183638  Baldwin County, AL         13.520173
# 2                              0.540406  Barbour County, AL         17.171214
# 3                              0.367041     Bibb County, AL          8.501098
# 4                              0.225584   Blount County, AL         14.035878

# %%
X = social_2020.iloc[:, 1:-2]
y = social_2020.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"percent_mobile_homes"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"percent_mobile_homes"], color=shap_values)
