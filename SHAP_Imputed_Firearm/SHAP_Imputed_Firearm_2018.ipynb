# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dask.dataframe as ddf
from pandas import Series, DataFrame
# %matplotlib inline

# %%
import seaborn as sn
import plotly.express as px

# %%
ur_files = ddf.read_csv('EnvironmentSuicide/Environment_Suicide_2018.csv', dtype = {'fips': str})
climate_2018 = ur_files.compute()
climate_2018 = climate_2018.loc[:, ~climate_2018.columns.str.contains('^Unnamed')]
climate_2018.head()
# Out:
#     fips   elevation  mean_temp  visibility  wind_speed  precipitation  \
# 0  01001   75.264706  65.815746    9.427348    4.089503       0.194157
# 1  01003   12.427907  68.342598         NaN    5.258610       0.000000
# 2  01005   94.311111  66.977961    9.317631    3.163085       0.139532
# 3  01007  162.637500  64.006027    8.989589    3.444932       0.187534
# 4  01009  243.931250  60.468767         NaN    4.017260       0.175918
#
#         fog      rain      snow  hail   thunder  Relative_Humidity  \
# 0  0.104972  0.546961  0.005525   0.0  0.157459          72.550842
# 1  0.000000  0.000000  0.000000   0.0  0.000000                NaN
# 2  0.121212  0.413223  0.005510   0.0  0.220386          73.359889
# 3  0.120548  0.400000  0.008219   0.0  0.131507          72.778657
# 4  0.000000  0.000000  0.000000   0.0  0.000000                NaN
#
#    Heat_Index  PM2.5  Ozone  rurality  SuicideDeathRate
# 0   65.507210    9.5    0.0         3         13.091628
# 1         NaN    7.2    0.0         4          8.714717
# 2   66.823672    9.0    0.0         6         20.426505
# 3   63.527227    9.4    1.0         2          9.477696
# 4         NaN    9.4    1.0         2         12.649308

# %%
climate_2018 = climate_2018[['fips', 'elevation', 'mean_temp', 'visibility', 'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail', 'thunder', 'Relative_Humidity', 'Heat_Index', 'PM2.5', 'Ozone', 'rurality','SuicideDeathRate']]

# %%
climate_2018 = climate_2018.dropna()

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
X = climate_2018.iloc[:, 1:-1].values
y = climate_2018.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.18713593, 0.09021842, 0.06051968, 0.09553164, 0.03859477,
#        0.06342733, 0.05337309, 0.05084027, 0.00218078, 0.03743348,
#        0.06209345, 0.0643381 , 0.07995158, 0.0269369 , 0.08742455])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = climate_2018.columns

# %%
columns = columns[1:-1]
columns = columns.tolist()
columns
# Out:
# ['elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'Relative_Humidity',
#  'Heat_Index',
#  'PM2.5',
#  'Ozone',
#  'rurality']

# %%
len(columns)
# Out:
# 15

# %%
plt.barh(columns, rf.feature_importances_)
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
sorted_idx
# Out:
# array([ 8, 13,  9,  4,  7,  6,  2, 10,  5, 11, 12, 14,  1,  3,  0])

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
rf.feature_importances_[sorted_idx]
# Out:
# array([0.00218078, 0.0269369 , 0.03743348, 0.03859477, 0.05084027,
#        0.05337309, 0.06051968, 0.06209345, 0.06342733, 0.0643381 ,
#        0.07995158, 0.08742455, 0.09021842, 0.09553164, 0.18713593])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
def correlation_matrix(df):
    """
    A function to calculate and plot
    correlation matrix of a DataFrame.
    """
    # Create the matrix
    matrix = df.corr()
    
    # Create cmap
    cmap = sn.diverging_palette(250, 15, s=75, l=40,
                             n=9, center="light", as_cmap=True)
    # Create a mask
    mask = np.triu(np.ones_like(matrix, dtype=bool))
    
    # Make figsize bigger
    fig, ax = plt.subplots(figsize=(16,12))
    
    # Plot the matrix
    _ = sn.heatmap(matrix, mask=mask, center=0, annot=True,
             fmt='.2f', square=True, cmap=cmap, ax=ax)

# %%
correlation_matrix(climate_2018)

# %% [markdown]
# ## Find the economic feature importances

# %%
ur_files = ddf.read_csv('SocialEconomicSuicide/Social_Economic_Suicide_2018.csv', dtype = {'fips': str, 'per_capita_income': float})
social_2018 = ur_files.compute()
social_2018 = social_2018.loc[:, ~social_2018.columns.str.contains('^Unnamed')]
social_2018.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  30061            23744.0               0.169757
# 1  30069            32565.0               0.083532
# 2  30077            25060.0               0.127172
# 3  30089            23822.0               0.194971
# 4  30109            23137.0               0.158033
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.113593              0.293249            0.036492
# 1                       0.011834              0.240741            0.005348
# 2                       0.114378              0.125810            0.031826
# 3                       0.111755              0.134527            0.026247
# 4                       0.126394              0.117493            0.030181
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.253785              0.031195                    0.003200
# 1                0.152672              0.016043                    0.000000
# 2                0.254481              0.036013                    0.003755
# 3                0.327786              0.011508                    0.002511
# 4                0.131535              0.006036                    0.008446
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.280218                           0.008909
# 1                  0.194444                           0.024570
# 2                  0.194578                           0.027816
# 3                  0.288603                           0.026843
# 4                  0.209362                           0.048571
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.180480            0.085015          0.636168
# 1                    0.199074            0.018519          0.587384
# 2                    0.146772            0.102900          0.496553
# 3                    0.179412            0.097908          0.556381
# 4                    0.285957            0.048511          0.534532
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.018523
# 1                                     0.000000
# 2                                     0.235388
# 3                                     0.020571
# 4                                     0.022128
#
#    percent_single_parent_households_CDC                county  \
# 0                              0.244681    Mineral County, MT
# 1                              0.430233  Petroleum County, MT
# 2                              0.168008     Powell County, MT
# 3                              0.175629    Sanders County, MT
# 4                              0.125000     Wibaux County, MT
#
#    SuicideDeathRate
# 0         15.994478
# 1         10.615910
# 2         16.871412
# 3         17.301295
# 4         10.615910

# %%
social_2018['SuicideDeathRate'].isna().sum()
# Out:
# 3

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
social_2018 = social_2018.dropna(how = 'any')

# %%
social_2018.shape
# Out:
# (3215, 18)

# %%
X = social_2018.iloc[:, 1:-2].values
y = social_2018.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.05313464, 0.04505581, 0.04674364, 0.27640104, 0.04490498,
#        0.04744862, 0.04420279, 0.03303979, 0.05729384, 0.0960286 ,
#        0.04214644, 0.05355511, 0.08779178, 0.03503829, 0.03721465])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = social_2018.columns
columns = columns[1:-2]
columns = columns.tolist()
columns
# Out:
# ['per_capita_income',
#  'percent_below_poverty',
#  'percent_no_highschool_diploma',
#  'percent_mobile_homes',
#  'percent_no_vehicle',
#  'percent_unemployed_CDC',
#  'percent_overcrowding',
#  'percent_multi_unit_housing',
#  'percent_age_65_and_older',
#  'percent_limited_english_abilities',
#  'percent_age_17_and_younger',
#  'percent_minorities',
#  'percent_disabled',
#  'percent_institutionalized_in_group_quarters',
#  'percent_single_parent_households_CDC']

# %%
social_2018.shape
# Out:
# (3215, 18)

# %%
climate_2018.shape
# Out:
# (2788, 17)

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
correlation_matrix(social_2018)

# %% [markdown]
# ## find the rank of importances of all factors

# %%
df_total = social_2018.merge(climate_2018, on = ['fips', 'SuicideDeathRate'], how = 'left')
df_total = df_total.dropna(how = 'any')
df_total.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  30061            23744.0               0.169757
# 2  30077            25060.0               0.127172
# 3  30089            23822.0               0.194971
# 4  30109            23137.0               0.158033
# 5  30031            34331.0               0.118921
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.113593              0.293249            0.036492
# 2                       0.114378              0.125810            0.031826
# 3                       0.111755              0.134527            0.026247
# 4                       0.126394              0.117493            0.030181
# 5                       0.033885              0.076931            0.033560
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.253785              0.031195                    0.003200
# 2                0.254481              0.036013                    0.003755
# 3                0.327786              0.011508                    0.002511
# 4                0.131535              0.006036                    0.008446
# 5                0.162148              0.015601                    0.070098
#
#    percent_age_65_and_older  ...       fog      rain      snow  hail  \
# 0                  0.280218  ...  0.439227  0.234807  0.433702   0.0
# 2                  0.194578  ...  0.060274  0.191781  0.172603   0.0
# 3                  0.288603  ...  0.439227  0.234807  0.433702   0.0
# 4                  0.209362  ...  0.054755  0.331412  0.207493   0.0
# 5                  0.117589  ...  0.082192  0.252055  0.189041   0.0
#
#     thunder  Relative_Humidity Heat_Index  PM2.5  Ozone  rurality
# 0  0.022099          63.801846  35.192416    9.1    0.0       6.0
# 2  0.046575          54.963256  41.516259    6.3    0.0       6.0
# 3  0.022099          63.801846  35.192416   11.0    0.0       6.0
# 4  0.048991          66.952032  38.364238    5.3    0.0       6.0
# 5  0.057534          60.680593  39.553933    3.5    0.0       5.0
#
# [5 rows x 33 columns]

# %%
col = df_total.columns.values

# %%
col
# Out:
# array(['fips', 'per_capita_income', 'percent_below_poverty',
#        'percent_no_highschool_diploma', 'percent_mobile_homes',
#        'percent_no_vehicle', 'percent_unemployed_CDC',
#        'percent_overcrowding', 'percent_multi_unit_housing',
#        'percent_age_65_and_older', 'percent_limited_english_abilities',
#        'percent_age_17_and_younger', 'percent_minorities',
#        'percent_disabled', 'percent_institutionalized_in_group_quarters',
#        'percent_single_parent_households_CDC', 'county',
#        'SuicideDeathRate', 'elevation', 'mean_temp', 'visibility',
#        'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail',
#        'thunder', 'Relative_Humidity', 'Heat_Index', 'PM2.5', 'Ozone',
#        'rurality'], dtype=object)

# %%
new_col = ['fips', 'county', 'percent_below_poverty',
       'per_capita_income', 'percent_unemployed_CDC',
       'percent_no_highschool_diploma', 'percent_age_65_and_older',
       'percent_age_17_and_younger', 'percent_disabled',
       'percent_single_parent_households_CDC', 'percent_minorities',
       'percent_limited_english_abilities', 'percent_multi_unit_housing',
       'percent_mobile_homes', 'percent_overcrowding',
       'percent_no_vehicle',
       'percent_institutionalized_in_group_quarters', 
       'elevation', 'mean_temp', 'visibility',
       'wind_speed', 'precipitation', 'Relative_Humidity', 'Heat_Index',
       'fog', 'rain', 'snow', 'hail', 'thunder', 'PM2.5',
       'Ozone', 'rurality','SuicideDeathRate']

# %%
df_total = df_total[new_col]

# %%
df_total.shape
# Out:
# (2788, 33)

# %%
df_total.head()
# Out:
#     fips               county  percent_below_poverty  per_capita_income  \
# 0  30061   Mineral County, MT               0.169757            23744.0
# 2  30077    Powell County, MT               0.127172            25060.0
# 3  30089   Sanders County, MT               0.194971            23822.0
# 4  30109    Wibaux County, MT               0.158033            23137.0
# 5  30031  Gallatin County, MT               0.118921            34331.0
#
#    percent_unemployed_CDC  percent_no_highschool_diploma  \
# 0                0.253785                       0.113593
# 2                0.254481                       0.114378
# 3                0.327786                       0.111755
# 4                0.131535                       0.126394
# 5                0.162148                       0.033885
#
#    percent_age_65_and_older  percent_age_17_and_younger  percent_disabled  \
# 0                  0.280218                    0.180480          0.636168
# 2                  0.194578                    0.146772          0.496553
# 3                  0.288603                    0.179412          0.556381
# 4                  0.209362                    0.285957          0.534532
# 5                  0.117589                    0.202618          0.334663
#
#    percent_single_parent_households_CDC  ...  Heat_Index       fog      rain  \
# 0                              0.244681  ...   35.192416  0.439227  0.234807
# 2                              0.168008  ...   41.516259  0.060274  0.191781
# 3                              0.175629  ...   35.192416  0.439227  0.234807
# 4                              0.125000  ...   38.364238  0.054755  0.331412
# 5                              0.130443  ...   39.553933  0.082192  0.252055
#
#        snow  hail   thunder  PM2.5  Ozone  rurality  SuicideDeathRate
# 0  0.433702   0.0  0.022099    9.1    0.0       6.0         15.994478
# 2  0.172603   0.0  0.046575    6.3    0.0       6.0         16.871412
# 3  0.433702   0.0  0.022099   11.0    0.0       6.0         17.301295
# 4  0.207493   0.0  0.048991    5.3    0.0       6.0         10.615910
# 5  0.189041   0.0  0.057534    3.5    0.0       5.0         12.513855
#
# [5 rows x 33 columns]

# %%
plt.rcParams.update({'figure.figsize': (20.0, 12.0)})
plt.rcParams.update({'font.size': 14})
X = df_total.iloc[:, 2:-1].values
y = df_total.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.02509375, 0.03626571, 0.02534639, 0.01497676, 0.04368687,
#        0.02180557, 0.06277504, 0.01677874, 0.01870385, 0.03830547,
#        0.01677235, 0.22338455, 0.02020222, 0.02157223, 0.01788612,
#        0.09079974, 0.02529227, 0.03143606, 0.03246108, 0.0208005 ,
#        0.03451636, 0.02817412, 0.01916441, 0.02642983, 0.02192635,
#        0.00080131, 0.01544848, 0.03288779, 0.00889045, 0.00741563])

# %%
len(rf.feature_importances_)
# Out:
# 30

# %%
columns = df_total.columns
columns = columns[2:-1]
columns = columns.tolist()
columns
# Out:
# ['percent_below_poverty',
#  'per_capita_income',
#  'percent_unemployed_CDC',
#  'percent_no_highschool_diploma',
#  'percent_age_65_and_older',
#  'percent_age_17_and_younger',
#  'percent_disabled',
#  'percent_single_parent_households_CDC',
#  'percent_minorities',
#  'percent_limited_english_abilities',
#  'percent_multi_unit_housing',
#  'percent_mobile_homes',
#  'percent_overcrowding',
#  'percent_no_vehicle',
#  'percent_institutionalized_in_group_quarters',
#  'elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'Relative_Humidity',
#  'Heat_Index',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'PM2.5',
#  'Ozone',
#  'rurality']

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %% [markdown]
# ## SHAP

# %%
import xgboost
import shap

# %%
X = climate_2018.iloc[:, 1:-1]
y = climate_2018.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"elevation"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"rurality"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:,"elevation"],shap_values[:,"rurality"], xmin=500)

# %%
shap.plots.scatter(shap_values[:,"elevation"],shap_values[:,"rurality"], xmin=800)

# %%
shap.plots.scatter(shap_values[:, "PM2.5"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"PM2.5"])

# %%
shap.plots.scatter(shap_values[:, "PM2.5"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"PM2.5"])

# %% [markdown]
# ### social economic factors

# %%
social_2018.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  30061            23744.0               0.169757
# 1  30069            32565.0               0.083532
# 2  30077            25060.0               0.127172
# 3  30089            23822.0               0.194971
# 4  30109            23137.0               0.158033
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.113593              0.293249            0.036492
# 1                       0.011834              0.240741            0.005348
# 2                       0.114378              0.125810            0.031826
# 3                       0.111755              0.134527            0.026247
# 4                       0.126394              0.117493            0.030181
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.253785              0.031195                    0.003200
# 1                0.152672              0.016043                    0.000000
# 2                0.254481              0.036013                    0.003755
# 3                0.327786              0.011508                    0.002511
# 4                0.131535              0.006036                    0.008446
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.280218                           0.008909
# 1                  0.194444                           0.024570
# 2                  0.194578                           0.027816
# 3                  0.288603                           0.026843
# 4                  0.209362                           0.048571
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.180480            0.085015          0.636168
# 1                    0.199074            0.018519          0.587384
# 2                    0.146772            0.102900          0.496553
# 3                    0.179412            0.097908          0.556381
# 4                    0.285957            0.048511          0.534532
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.018523
# 1                                     0.000000
# 2                                     0.235388
# 3                                     0.020571
# 4                                     0.022128
#
#    percent_single_parent_households_CDC                county  \
# 0                              0.244681    Mineral County, MT
# 1                              0.430233  Petroleum County, MT
# 2                              0.168008     Powell County, MT
# 3                              0.175629    Sanders County, MT
# 4                              0.125000     Wibaux County, MT
#
#    SuicideDeathRate
# 0         15.994478
# 1         10.615910
# 2         16.871412
# 3         17.301295
# 4         10.615910

# %%
X = social_2018.iloc[:, 1:-2]
y = social_2018.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"percent_mobile_homes"], color=shap_values)
