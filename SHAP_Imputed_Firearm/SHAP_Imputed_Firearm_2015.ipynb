# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dask.dataframe as ddf
from pandas import Series, DataFrame
# %matplotlib inline

# %%
import seaborn as sn
import plotly.express as px

# %%
ur_files = ddf.read_csv('EnvironmentSuicide/Environment_Suicide_2015.csv', dtype = {'fips': str})
climate_2015 = ur_files.compute()
climate_2015 = climate_2015.loc[:, ~climate_2015.columns.str.contains('^Unnamed')]
climate_2015.head()
# Out:
#     fips   elevation  mean_temp  visibility  wind_speed  precipitation  \
# 0  01001   75.264706  66.322802    9.384341    4.497802       0.155882
# 1  01003   12.427907  69.414648         NaN    5.756338       0.000000
# 2  01005   94.311111  67.177808    9.035933    2.735616       0.164795
# 3  01007  162.637500  64.461918    8.992329    3.349315       0.180301
# 4  01009  243.931250  60.541644         NaN    4.052877       0.149288
#
#         fog      rain      snow  hail   thunder  Relative_Humidity  \
# 0  0.156593  0.508242  0.000000   0.0  0.173077          72.034699
# 1  0.000000  0.000000  0.000000   0.0  0.000000                NaN
# 2  0.156164  0.443836  0.013699   0.0  0.230137          71.681434
# 3  0.112329  0.427397  0.010959   0.0  0.175342          70.591332
# 4  0.000000  0.000000  0.000000   0.0  0.000000                NaN
#
#    Heat_Index  humidity_temp_index  PM2.5  Ozone  rurality  SuicideDeathRate
# 0   66.040713            65.520556   10.8    0.0         3          9.889824
# 1         NaN            68.585925    8.6    1.0         4         16.199579
# 2   66.964616            64.423201    9.9    0.0         6         10.409531
# 3   63.925902            63.157399   10.5    0.0         2          9.628611
# 4         NaN            63.488756   10.8    1.0         2         12.781537

# %%
climate_2015 = climate_2015[['fips', 'elevation', 'mean_temp', 'visibility', 'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail', 'thunder', 'Relative_Humidity', 'Heat_Index', 'humidity_temp_index','PM2.5', 'Ozone', 'rurality','SuicideDeathRate']]

# %%
climate_2015 = climate_2015.dropna()

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
X = climate_2015.iloc[:, 1:-1].values
y = climate_2015.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.18967627, 0.0432715 , 0.05173314, 0.06341177, 0.05009968,
#        0.04652664, 0.04685277, 0.03591328, 0.00219793, 0.03859947,
#        0.0609423 , 0.04241678, 0.16752528, 0.05538691, 0.02165406,
#        0.08379223])

# %%
len(rf.feature_importances_)
# Out:
# 16

# %%
columns = climate_2015.columns

# %%
columns = columns[1:-1]
columns = columns.tolist()
columns
# Out:
# ['elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'Relative_Humidity',
#  'Heat_Index',
#  'humidity_temp_index',
#  'PM2.5',
#  'Ozone',
#  'rurality']

# %%
len(columns)
# Out:
# 16

# %%
plt.barh(columns, rf.feature_importances_)
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
sorted_idx
# Out:
# array([ 8, 14,  7,  9, 11,  1,  5,  6,  4,  2, 13, 10,  3, 15, 12,  0])

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
rf.feature_importances_[sorted_idx]
# Out:
# array([0.00219793, 0.02165406, 0.03591328, 0.03859947, 0.04241678,
#        0.0432715 , 0.04652664, 0.04685277, 0.05009968, 0.05173314,
#        0.05538691, 0.0609423 , 0.06341177, 0.08379223, 0.16752528,
#        0.18967627])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
def correlation_matrix(df):
    """
    A function to calculate and plot
    correlation matrix of a DataFrame.
    """
    # Create the matrix
    matrix = df.corr()
    
    # Create cmap
    cmap = sn.diverging_palette(250, 15, s=75, l=40,
                             n=9, center="light", as_cmap=True)
    # Create a mask
    mask = np.triu(np.ones_like(matrix, dtype=bool))
    
    # Make figsize bigger
    fig, ax = plt.subplots(figsize=(16,12))
    
    # Plot the matrix
    _ = sn.heatmap(matrix, mask=mask, center=0, annot=True,
             fmt='.2f', square=True, cmap=cmap, ax=ax)

# %%
correlation_matrix(climate_2015)

# %% [markdown]
# ## Find the economic feature importances

# %%
ur_files = ddf.read_csv('SocialEconomicSuicide/Social_Economic_Suicide_2015.csv', dtype = {'fips': str, 'per_capita_income': float})
social_2015 = ur_files.compute()
social_2015 = social_2015.loc[:, ~social_2015.columns.str.contains('^Unnamed')]
social_2015.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  48075            19861.0               0.202129
# 1  48091            32838.0               0.088030
# 2  48225            17570.0               0.250114
# 3  48349            20697.0               0.207390
# 4  48415            24584.0               0.098580
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.134623              0.118496            0.065245
# 1                       0.102615              0.112378            0.030648
# 2                       0.185562              0.226235            0.079667
# 3                       0.233678              0.208703            0.084626
# 4                       0.195417              0.081656            0.021605
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.380798              0.008783                    0.089077
# 1                0.201620              0.030443                    0.061386
# 2                0.285797              0.021129                    0.013428
# 3                0.241346              0.049837                    0.028633
# 4                0.226319              0.045953                    0.005885
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.144496                           0.125595
# 1                  0.169319                           0.167108
# 2                  0.203277                           0.074835
# 3                  0.157135                           0.207070
# 4                  0.141432                           0.269313
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.201870            0.356566          0.550904
# 1                    0.231920            0.306398          0.507119
# 2                    0.195172            0.380714          0.535010
# 3                    0.262958            0.416040          0.691226
# 4                    0.252872            0.449240          0.595390
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.175096
# 1                                     0.009153
# 2                                     0.140965
# 3                                     0.017561
# 4                                     0.103434
#
#    percent_single_parent_households_CDC                county  \
# 0                              0.246253  Childress County, TX
# 1                              0.189647      Comal County, TX
# 2                              0.343124    Houston County, TX
# 3                              0.274059    Navarro County, TX
# 4                              0.235834     Scurry County, TX
#
#    SuicideDeathRate
# 0          7.592726
# 1          9.298866
# 2         15.901941
# 3         20.694079
# 4          8.930384

# %%
social_2015['SuicideDeathRate'].isna().sum()
# Out:
# 122

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
social_2015 = social_2015.dropna(how = 'any')

# %%
social_2015.shape
# Out:
# (3098, 18)

# %%
X = social_2015.iloc[:, 1:-2].values
y = social_2015.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.04270967, 0.03729607, 0.05106406, 0.24742706, 0.04907785,
#        0.04330165, 0.04672237, 0.0393423 , 0.06931567, 0.06966327,
#        0.06113913, 0.07013386, 0.08577652, 0.04539552, 0.04163498])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = social_2015.columns
columns = columns[1:-2]
columns = columns.tolist()
columns
# Out:
# ['per_capita_income',
#  'percent_below_poverty',
#  'percent_no_highschool_diploma',
#  'percent_mobile_homes',
#  'percent_no_vehicle',
#  'percent_unemployed_CDC',
#  'percent_overcrowding',
#  'percent_multi_unit_housing',
#  'percent_age_65_and_older',
#  'percent_limited_english_abilities',
#  'percent_age_17_and_younger',
#  'percent_minorities',
#  'percent_disabled',
#  'percent_institutionalized_in_group_quarters',
#  'percent_single_parent_households_CDC']

# %%
social_2015.shape
# Out:
# (3098, 18)

# %%
climate_2015.shape
# Out:
# (2750, 18)

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
correlation_matrix(social_2015)

# %% [markdown]
# ## find the rank of importances of all factors

# %%
df_total = social_2015.merge(climate_2015, on = ['fips', 'SuicideDeathRate'], how = 'left')
df_total = df_total.dropna(how = 'any')
df_total.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  48075            19861.0               0.202129
# 1  48091            32838.0               0.088030
# 2  48225            17570.0               0.250114
# 3  48349            20697.0               0.207390
# 4  48415            24584.0               0.098580
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.134623              0.118496            0.065245
# 1                       0.102615              0.112378            0.030648
# 2                       0.185562              0.226235            0.079667
# 3                       0.233678              0.208703            0.084626
# 4                       0.195417              0.081656            0.021605
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.380798              0.008783                    0.089077
# 1                0.201620              0.030443                    0.061386
# 2                0.285797              0.021129                    0.013428
# 3                0.241346              0.049837                    0.028633
# 4                0.226319              0.045953                    0.005885
#
#    percent_age_65_and_older  ...      rain      snow  hail   thunder  \
# 0                  0.144496  ...  0.269972  0.046832   0.0  0.123967
# 1                  0.169319  ...  0.326027  0.010959   0.0  0.104110
# 2                  0.203277  ...  0.366782  0.003460   0.0  0.069204
# 3                  0.157135  ...  0.353425  0.021918   0.0  0.139726
# 4                  0.141432  ...  0.272727  0.060606   0.0  0.006061
#
#    Relative_Humidity  Heat_Index humidity_temp_index  PM2.5  Ozone  rurality
# 0          55.342963   61.367180           60.087092    6.9    0.0       6.0
# 1          67.037802   69.188968           66.613291    9.2   10.0       2.0
# 2          72.467798   65.101177           64.217477    9.3    1.0       6.0
# 3          64.823363   67.186862           64.274269    9.2    1.0       5.0
# 4          58.234932   63.369708           63.876485    7.1    0.0       5.0
#
# [5 rows x 34 columns]

# %%
col = df_total.columns.values

# %%
col
# Out:
# array(['fips', 'per_capita_income', 'percent_below_poverty',
#        'percent_no_highschool_diploma', 'percent_mobile_homes',
#        'percent_no_vehicle', 'percent_unemployed_CDC',
#        'percent_overcrowding', 'percent_multi_unit_housing',
#        'percent_age_65_and_older', 'percent_limited_english_abilities',
#        'percent_age_17_and_younger', 'percent_minorities',
#        'percent_disabled', 'percent_institutionalized_in_group_quarters',
#        'percent_single_parent_households_CDC', 'county',
#        'SuicideDeathRate', 'elevation', 'mean_temp', 'visibility',
#        'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail',
#        'thunder', 'Relative_Humidity', 'Heat_Index',
#        'humidity_temp_index', 'PM2.5', 'Ozone', 'rurality'], dtype=object)

# %%
new_col = ['fips', 'county', 'percent_below_poverty',
       'per_capita_income', 'percent_unemployed_CDC',
       'percent_no_highschool_diploma', 'percent_age_65_and_older',
       'percent_age_17_and_younger', 'percent_disabled',
       'percent_single_parent_households_CDC', 'percent_minorities',
       'percent_limited_english_abilities', 'percent_multi_unit_housing',
       'percent_mobile_homes', 'percent_overcrowding',
       'percent_no_vehicle',
       'percent_institutionalized_in_group_quarters', 
       'elevation', 'mean_temp', 'visibility',
       'wind_speed', 'precipitation', 'Relative_Humidity', 'Heat_Index','humidity_temp_index',
       'fog', 'rain', 'snow', 'hail', 'thunder', 'PM2.5',
       'Ozone', 'rurality','SuicideDeathRate']

# %%
df_total = df_total[new_col]

# %%
df_total.shape
# Out:
# (2750, 34)

# %%
df_total.head()
# Out:
#     fips                county  percent_below_poverty  per_capita_income  \
# 0  48075  Childress County, TX               0.202129            19861.0
# 1  48091      Comal County, TX               0.088030            32838.0
# 2  48225    Houston County, TX               0.250114            17570.0
# 3  48349    Navarro County, TX               0.207390            20697.0
# 4  48415     Scurry County, TX               0.098580            24584.0
#
#    percent_unemployed_CDC  percent_no_highschool_diploma  \
# 0                0.380798                       0.134623
# 1                0.201620                       0.102615
# 2                0.285797                       0.185562
# 3                0.241346                       0.233678
# 4                0.226319                       0.195417
#
#    percent_age_65_and_older  percent_age_17_and_younger  percent_disabled  \
# 0                  0.144496                    0.201870          0.550904
# 1                  0.169319                    0.231920          0.507119
# 2                  0.203277                    0.195172          0.535010
# 3                  0.157135                    0.262958          0.691226
# 4                  0.141432                    0.252872          0.595390
#
#    percent_single_parent_households_CDC  ...  humidity_temp_index       fog  \
# 0                              0.246253  ...            60.087092  0.085399
# 1                              0.189647  ...            66.613291  0.123288
# 2                              0.343124  ...            64.217477  0.121107
# 3                              0.274059  ...            64.274269  0.063014
# 4                              0.235834  ...            63.876485  0.057576
#
#        rain      snow  hail   thunder  PM2.5  Ozone  rurality  \
# 0  0.269972  0.046832   0.0  0.123967    6.9    0.0       6.0
# 1  0.326027  0.010959   0.0  0.104110    9.2   10.0       2.0
# 2  0.366782  0.003460   0.0  0.069204    9.3    1.0       6.0
# 3  0.353425  0.021918   0.0  0.139726    9.2    1.0       5.0
# 4  0.272727  0.060606   0.0  0.006061    7.1    0.0       5.0
#
#    SuicideDeathRate
# 0          7.592726
# 1          9.298866
# 2         15.901941
# 3         20.694079
# 4          8.930384
#
# [5 rows x 34 columns]

# %%
plt.rcParams.update({'figure.figsize': (20.0, 12.0)})
plt.rcParams.update({'font.size': 14})
X = df_total.iloc[:, 2:-1].values
y = df_total.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.01616132, 0.02159037, 0.01920208, 0.01637132, 0.02858297,
#        0.02413849, 0.05704085, 0.0147708 , 0.03324254, 0.05118322,
#        0.01758781, 0.22248443, 0.01587042, 0.01898637, 0.02011084,
#        0.10130749, 0.02300744, 0.02491861, 0.02692269, 0.02210974,
#        0.02892608, 0.02433824, 0.04055477, 0.0273643 , 0.02237112,
#        0.0184402 , 0.00160034, 0.01914389, 0.02287669, 0.01175395,
#        0.0070406 ])

# %%
len(rf.feature_importances_)
# Out:
# 31

# %%
columns = df_total.columns
columns = columns[2:-1]
columns = columns.tolist()
columns
# Out:
# ['percent_below_poverty',
#  'per_capita_income',
#  'percent_unemployed_CDC',
#  'percent_no_highschool_diploma',
#  'percent_age_65_and_older',
#  'percent_age_17_and_younger',
#  'percent_disabled',
#  'percent_single_parent_households_CDC',
#  'percent_minorities',
#  'percent_limited_english_abilities',
#  'percent_multi_unit_housing',
#  'percent_mobile_homes',
#  'percent_overcrowding',
#  'percent_no_vehicle',
#  'percent_institutionalized_in_group_quarters',
#  'elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'Relative_Humidity',
#  'Heat_Index',
#  'humidity_temp_index',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'PM2.5',
#  'Ozone',
#  'rurality']

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %% [markdown]
# ## SHAP

# %%
import xgboost
import shap

# %%
X = climate_2015.iloc[:, 1:-1]
y = climate_2015.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"elevation"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"rurality"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"mean_temp"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:,"elevation"],shap_values[:,"rurality"], xmin=500)

# %%
shap.plots.scatter(shap_values[:, "PM2.5"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"PM2.5"])

# %%
shap.plots.scatter(shap_values[:, "PM2.5"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"PM2.5"])

# %% [markdown]
# ### social economic factors

# %%
social_2015.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  48075            19861.0               0.202129
# 1  48091            32838.0               0.088030
# 2  48225            17570.0               0.250114
# 3  48349            20697.0               0.207390
# 4  48415            24584.0               0.098580
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.134623              0.118496            0.065245
# 1                       0.102615              0.112378            0.030648
# 2                       0.185562              0.226235            0.079667
# 3                       0.233678              0.208703            0.084626
# 4                       0.195417              0.081656            0.021605
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.380798              0.008783                    0.089077
# 1                0.201620              0.030443                    0.061386
# 2                0.285797              0.021129                    0.013428
# 3                0.241346              0.049837                    0.028633
# 4                0.226319              0.045953                    0.005885
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.144496                           0.125595
# 1                  0.169319                           0.167108
# 2                  0.203277                           0.074835
# 3                  0.157135                           0.207070
# 4                  0.141432                           0.269313
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.201870            0.356566          0.550904
# 1                    0.231920            0.306398          0.507119
# 2                    0.195172            0.380714          0.535010
# 3                    0.262958            0.416040          0.691226
# 4                    0.252872            0.449240          0.595390
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.175096
# 1                                     0.009153
# 2                                     0.140965
# 3                                     0.017561
# 4                                     0.103434
#
#    percent_single_parent_households_CDC                county  \
# 0                              0.246253  Childress County, TX
# 1                              0.189647      Comal County, TX
# 2                              0.343124    Houston County, TX
# 3                              0.274059    Navarro County, TX
# 4                              0.235834     Scurry County, TX
#
#    SuicideDeathRate
# 0          7.592726
# 1          9.298866
# 2         15.901941
# 3         20.694079
# 4          8.930384

# %%
X = social_2015.iloc[:, 1:-2]
y = social_2015.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"percent_mobile_homes"], color=shap_values)
