# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dask.dataframe as ddf
from pandas import Series, DataFrame
# %matplotlib inline

# %%
import seaborn as sn
import plotly.express as px

# %%
ur_files = ddf.read_csv('EnvironmentSuicide/Environment_Suicide_2012.csv', dtype = {'fips': str})
climate_2012 = ur_files.compute()
climate_2012 = climate_2012.loc[:, ~climate_2012.columns.str.contains('^Unnamed')]
climate_2012.head()
# Out:
#     fips   elevation  mean_temp  visibility  wind_speed  precipitation  \
# 0  01001   75.264706  66.724100    9.432410    3.995014       0.130734
# 1  01003   12.427907  70.237901         NaN    5.686297       0.000000
# 2  01005   94.311111  67.143836    9.188219    2.814521       0.131071
# 3  01007  162.637500  65.122131    9.145355    2.943716       0.162814
# 4  01009  243.931250  61.504372         NaN    3.992623       0.156503
#
#         fog      rain      snow  hail   thunder  Relative_Humidity  \
# 0  0.166205  0.523546  0.000000   0.0  0.199446          69.429011
# 1  0.000000  0.000000  0.000000   0.0  0.000000                NaN
# 2  0.128767  0.652055  0.019178   0.0  0.197260          67.716385
# 3  0.098361  0.346995  0.000000   0.0  0.142077          68.108761
# 4  0.000000  0.000000  0.000000   0.0  0.000000                NaN
#
#    Heat_Index  PM2.5  Ozone  rurality  SuicideDeathRate
# 0   66.359673   10.8    0.0         3          9.124524
# 1         NaN    9.2    2.0         5         14.675822
# 2   66.740889   10.1    0.0         5          9.486363
# 3   64.535456   10.5    2.0         2          8.613137
# 4         NaN   11.3    8.0         2         15.803146

# %%
climate_2012 = climate_2012[['fips', 'elevation', 'mean_temp', 'visibility', 'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail', 'thunder', 'Relative_Humidity', 'Heat_Index', 'PM2.5', 'Ozone', 'rurality', 'SuicideDeathRate']]

# %%
climate_2012 = climate_2012.dropna()

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
X = climate_2012.iloc[:, 1:-1].values
y = climate_2012.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.18458662, 0.08604367, 0.04829825, 0.06260346, 0.05132987,
#        0.03997589, 0.06172192, 0.0340098 , 0.00442272, 0.03506477,
#        0.08448147, 0.1129718 , 0.06620081, 0.06050366, 0.06778529])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = climate_2012.columns

# %%
columns = columns[1:-1]
columns = columns.tolist()
columns
# Out:
# ['elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'Relative_Humidity',
#  'Heat_Index',
#  'PM2.5',
#  'Ozone',
#  'rurality']

# %%
len(columns)
# Out:
# 15

# %%
plt.barh(columns, rf.feature_importances_)
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
sorted_idx
# Out:
# array([ 8,  7,  9,  5,  2,  4, 13,  6,  3, 12, 14, 10,  1, 11,  0])

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
rf.feature_importances_[sorted_idx]
# Out:
# array([0.00442272, 0.0340098 , 0.03506477, 0.03997589, 0.04829825,
#        0.05132987, 0.06050366, 0.06172192, 0.06260346, 0.06620081,
#        0.06778529, 0.08448147, 0.08604367, 0.1129718 , 0.18458662])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
def correlation_matrix(df):
    """
    A function to calculate and plot
    correlation matrix of a DataFrame.
    """
    # Create the matrix
    matrix = df.corr()
    
    # Create cmap
    cmap = sn.diverging_palette(250, 15, s=75, l=40,
                             n=9, center="light", as_cmap=True)
    # Create a mask
    mask = np.triu(np.ones_like(matrix, dtype=bool))
    
    # Make figsize bigger
    fig, ax = plt.subplots(figsize=(16,12))
    
    # Plot the matrix
    _ = sn.heatmap(matrix, mask=mask, center=0, annot=True,
             fmt='.2f', square=True, cmap=cmap, ax=ax)

# %%
correlation_matrix(climate_2012)

# %% [markdown]
# ## Find the economic feature importances

# %%
ur_files = ddf.read_csv('SocialEconomicSuicide/Social_Economic_Suicide_2012.csv', dtype = {'fips': str, 'per_capita_income': float})
social_2012 = ur_files.compute()
social_2012 = social_2012.loc[:, ~social_2012.columns.str.contains('^Unnamed')]
social_2012.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  29115            20968.0               0.134391
# 1  29091            17763.0               0.206424
# 2  29101            21375.0               0.165849
# 3  29105            19788.0               0.185112
# 4  29125            21883.0               0.142525
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.116955              0.078064            0.079007
# 1                       0.164695              0.150430            0.075740
# 2                       0.092846              0.092393            0.045383
# 3                       0.195041              0.214846            0.062743
# 4                       0.167517              0.121296            0.030032
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.232133              0.015596                    0.008530
# 1                0.257840              0.008010                    0.031344
# 2                0.265229              0.017202                    0.047146
# 3                0.232628              0.024490                    0.030122
# 4                0.213871              0.018398                    0.018954
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.191664                           0.027107
# 1                  0.171907                           0.031756
# 2                  0.106978                           0.038803
# 3                  0.156195                           0.027297
# 4                  0.180197                           0.014222
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.242738            0.036865               NaN
# 1                    0.248054            0.047954               NaN
# 2                    0.226191            0.120365               NaN
# 3                    0.249190            0.054524               NaN
# 4                    0.233917            0.033589               NaN
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.015077
# 1                                     0.016787
# 2                                     0.079186
# 3                                     0.009773
# 4                                     0.010503
#
#    percent_single_parent_households_CDC              county  SuicideDeathRate
# 0                              0.190942     Linn County, MO          8.900228
# 1                              0.241676   Howell County, MO         20.834587
# 2                              0.199281  Johnson County, MO          9.594417
# 3                              0.233273  Laclede County, MO          7.453974
# 4                              0.261459   Maries County, MO         13.989307

# %%
social_2012['SuicideDeathRate'].isna().sum()
# Out:
# 130

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
social_2012 = social_2012.dropna(how = 'any')

# %%
social_2012.shape
# Out:
# (812, 18)

# %%
X = social_2012.iloc[:, 1:-2].values
y = social_2012.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.03067505, 0.03966255, 0.03151388, 0.33142839, 0.05571575,
#        0.06154926, 0.04711506, 0.04538918, 0.07190696, 0.08671921,
#        0.03125428, 0.04642908, 0.06001984, 0.03279255, 0.02782894])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = social_2012.columns
columns = columns[1:-2]
columns = columns.tolist()
columns
# Out:
# ['per_capita_income',
#  'percent_below_poverty',
#  'percent_no_highschool_diploma',
#  'percent_mobile_homes',
#  'percent_no_vehicle',
#  'percent_unemployed_CDC',
#  'percent_overcrowding',
#  'percent_multi_unit_housing',
#  'percent_age_65_and_older',
#  'percent_limited_english_abilities',
#  'percent_age_17_and_younger',
#  'percent_minorities',
#  'percent_disabled',
#  'percent_institutionalized_in_group_quarters',
#  'percent_single_parent_households_CDC']

# %%
social_2012.shape
# Out:
# (812, 18)

# %%
climate_2012.shape
# Out:
# (2711, 17)

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
correlation_matrix(social_2012)

# %% [markdown]
# ## find the rank of importances of all factors

# %%
df_total = social_2012.merge(climate_2012, on = ['fips', 'SuicideDeathRate'], how = 'left')
df_total = df_total.dropna(how = 'any')
df_total.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  29165            35133.0               0.073289
# 1  29187            18893.0               0.183494
# 2  29510            22551.0               0.270447
# 3  29043            24879.0               0.100910
# 4  29097            20801.0               0.189476
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.062224              0.010595            0.042211
# 1                       0.215348              0.152066            0.067276
# 2                       0.183196              0.003923            0.214116
# 3                       0.086901              0.035471            0.029257
# 4                       0.175963              0.067591            0.073836
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.153765              0.010497                    0.136781
# 1                0.282769              0.022141                    0.042700
# 2                0.272695              0.023298                    0.171784
# 3                0.176153              0.021015                    0.038032
# 4                0.204560              0.025997                    0.040460
#
#    percent_age_65_and_older  ...       fog      rain      snow      hail  \
# 0                  0.113390  ...  0.040984  0.265027  0.046448  0.002732
# 1                  0.143963  ...  0.000000  0.120879  0.000000  0.000000
# 2                  0.111105  ...  0.068306  0.319672  0.032787  0.002732
# 3                  0.124648  ...  0.054645  0.278689  0.024590  0.000000
# 4                  0.132429  ...  0.057377  0.259563  0.024590  0.000000
#
#     thunder  Relative_Humidity Heat_Index  PM2.5  Ozone  rurality
# 0  0.109290          56.604308  57.147397   10.5   34.0       2.0
# 1  0.120879          61.511177  56.869404    9.8   19.0       5.0
# 2  0.090164          60.844078  57.953469   10.5   29.0       1.0
# 3  0.103825          58.843497  57.857639    9.9   17.0       3.0
# 4  0.120219          58.536838  60.189291    9.9   23.0       4.0
#
# [5 rows x 33 columns]

# %%
col = df_total.columns.values

# %%
col
# Out:
# array(['fips', 'per_capita_income', 'percent_below_poverty',
#        'percent_no_highschool_diploma', 'percent_mobile_homes',
#        'percent_no_vehicle', 'percent_unemployed_CDC',
#        'percent_overcrowding', 'percent_multi_unit_housing',
#        'percent_age_65_and_older', 'percent_limited_english_abilities',
#        'percent_age_17_and_younger', 'percent_minorities',
#        'percent_disabled', 'percent_institutionalized_in_group_quarters',
#        'percent_single_parent_households_CDC', 'county',
#        'SuicideDeathRate', 'elevation', 'mean_temp', 'visibility',
#        'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail',
#        'thunder', 'Relative_Humidity', 'Heat_Index', 'PM2.5', 'Ozone',
#        'rurality'], dtype=object)

# %%
new_col = ['fips', 'county', 'percent_below_poverty',
       'per_capita_income', 'percent_unemployed_CDC',
       'percent_no_highschool_diploma', 'percent_age_65_and_older',
       'percent_age_17_and_younger', 'percent_disabled',
       'percent_single_parent_households_CDC', 'percent_minorities',
       'percent_limited_english_abilities', 'percent_multi_unit_housing',
       'percent_mobile_homes', 'percent_overcrowding',
       'percent_no_vehicle',
       'percent_institutionalized_in_group_quarters', 
       'elevation', 'mean_temp', 'visibility',
       'wind_speed', 'precipitation', 'Relative_Humidity', 'Heat_Index',
       'fog', 'rain', 'snow', 'hail', 'thunder', 'PM2.5',
       'Ozone', 'rurality','SuicideDeathRate']

# %%
df_total = df_total[new_col]

# %%
df_total.shape
# Out:
# (744, 33)

# %%
df_total.head()
# Out:
#     fips                   county  percent_below_poverty  per_capita_income  \
# 0  29165        Platte County, MO               0.073289            35133.0
# 1  29187  St. Francois County, MO               0.183494            18893.0
# 2  29510       St. Louis city, MO               0.270447            22551.0
# 3  29043     Christian County, MO               0.100910            24879.0
# 4  29097        Jasper County, MO               0.189476            20801.0
#
#    percent_unemployed_CDC  percent_no_highschool_diploma  \
# 0                0.153765                       0.062224
# 1                0.282769                       0.215348
# 2                0.272695                       0.183196
# 3                0.176153                       0.086901
# 4                0.204560                       0.175963
#
#    percent_age_65_and_older  percent_age_17_and_younger  percent_disabled  \
# 0                  0.113390                    0.243683          0.486545
# 1                  0.143963                    0.213055          0.679569
# 2                  0.111105                    0.214914          0.481358
# 3                  0.124648                    0.271433          0.482978
# 4                  0.132429                    0.257784          0.538774
#
#    percent_single_parent_households_CDC  ...  Heat_Index       fog      rain  \
# 0                              0.222380  ...   57.147397  0.040984  0.265027
# 1                              0.223660  ...   56.869404  0.000000  0.120879
# 2                              0.530968  ...   57.953469  0.068306  0.319672
# 3                              0.167453  ...   57.857639  0.054645  0.278689
# 4                              0.266611  ...   60.189291  0.057377  0.259563
#
#        snow      hail   thunder  PM2.5  Ozone  rurality  SuicideDeathRate
# 0  0.046448  0.002732  0.109290   10.5   34.0       2.0          9.291536
# 1  0.000000  0.000000  0.120879    9.8   19.0       5.0         14.077535
# 2  0.032787  0.002732  0.090164   10.5   29.0       1.0          5.971613
# 3  0.024590  0.000000  0.103825    9.9   17.0       3.0         13.780317
# 4  0.024590  0.000000  0.120219    9.9   23.0       4.0         11.279044
#
# [5 rows x 33 columns]

# %%
plt.rcParams.update({'figure.figsize': (20.0, 12.0)})
plt.rcParams.update({'font.size': 14})
X = df_total.iloc[:, 2:-1].values
y = df_total.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.01921609, 0.01712104, 0.02205592, 0.01022902, 0.03661754,
#        0.01337601, 0.03372146, 0.01680318, 0.02233789, 0.04857985,
#        0.02386564, 0.31414578, 0.0336958 , 0.01707634, 0.0167289 ,
#        0.05012889, 0.01021698, 0.03396012, 0.02073391, 0.01772796,
#        0.03418828, 0.01138931, 0.01897451, 0.02386285, 0.02162456,
#        0.0080356 , 0.01830462, 0.04318265, 0.02304423, 0.01905509])

# %%
len(rf.feature_importances_)
# Out:
# 30

# %%
columns = df_total.columns
columns = columns[2:-1]
columns = columns.tolist()
columns
# Out:
# ['percent_below_poverty',
#  'per_capita_income',
#  'percent_unemployed_CDC',
#  'percent_no_highschool_diploma',
#  'percent_age_65_and_older',
#  'percent_age_17_and_younger',
#  'percent_disabled',
#  'percent_single_parent_households_CDC',
#  'percent_minorities',
#  'percent_limited_english_abilities',
#  'percent_multi_unit_housing',
#  'percent_mobile_homes',
#  'percent_overcrowding',
#  'percent_no_vehicle',
#  'percent_institutionalized_in_group_quarters',
#  'elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'Relative_Humidity',
#  'Heat_Index',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'PM2.5',
#  'Ozone',
#  'rurality']

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %% [markdown]
# ## SHAP

# %%
import xgboost
import shap

# %%
X = climate_2012.iloc[:, 1:-1]
y = climate_2012.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"elevation"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"rurality"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"mean_temp"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:,"elevation"],shap_values[:,"rurality"], xmin=500)

# %%
shap.plots.scatter(shap_values[:,"elevation"],shap_values[:,"rurality"], xmin=600)

# %%
shap.plots.scatter(shap_values[:, "PM2.5"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"PM2.5"])

# %%
shap.plots.scatter(shap_values[:, "PM2.5"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"PM2.5"])

# %% [markdown]
# ### social econimic factors

# %%
social_2012.head()
# Out:
#      fips  per_capita_income  percent_below_poverty  \
# 6   29165            35133.0               0.073289
# 7   29187            18893.0               0.183494
# 8   29510            22551.0               0.270447
# 19  29043            24879.0               0.100910
# 27  29097            20801.0               0.189476
#
#     percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 6                        0.062224              0.010595            0.042211
# 7                        0.215348              0.152066            0.067276
# 8                        0.183196              0.003923            0.214116
# 19                       0.086901              0.035471            0.029257
# 27                       0.175963              0.067591            0.073836
#
#     percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 6                 0.153765              0.010497                    0.136781
# 7                 0.282769              0.022141                    0.042700
# 8                 0.272695              0.023298                    0.171784
# 19                0.176153              0.021015                    0.038032
# 27                0.204560              0.025997                    0.040460
#
#     percent_age_65_and_older  percent_limited_english_abilities  \
# 6                   0.113390                           0.067304
# 7                   0.143963                           0.021944
# 8                   0.111105                           0.088802
# 19                  0.124648                           0.032617
# 27                  0.132429                           0.068381
#
#     percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 6                     0.243683            0.156922          0.486545
# 7                     0.213055            0.072648          0.679569
# 8                     0.214914            0.577490          0.481358
# 19                    0.271433            0.058704          0.482978
# 27                    0.257784            0.138240          0.538774
#
#     percent_institutionalized_in_group_quarters  \
# 6                                      0.009434
# 7                                      0.121019
# 8                                      0.034835
# 19                                     0.007306
# 27                                     0.020181
#
#     percent_single_parent_households_CDC                   county  \
# 6                               0.222380        Platte County, MO
# 7                               0.223660  St. Francois County, MO
# 8                               0.530968       St. Louis city, MO
# 19                              0.167453     Christian County, MO
# 27                              0.266611        Jasper County, MO
#
#     SuicideDeathRate
# 6           9.291536
# 7          14.077535
# 8           5.971613
# 19         13.780317
# 27         11.279044

# %%
X = social_2012.iloc[:, 1:-2]
y = social_2012.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"percent_mobile_homes"], color=shap_values)
