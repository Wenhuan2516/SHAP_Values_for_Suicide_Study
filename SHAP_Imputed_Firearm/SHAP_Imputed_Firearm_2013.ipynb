# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dask.dataframe as ddf
from pandas import Series, DataFrame
# %matplotlib inline

# %%
import seaborn as sn
import plotly.express as px

# %%
ur_files = ddf.read_csv('EnvironmentSuicide/Environment_Suicide_2013.csv', dtype = {'fips': str})
climate_2013 = ur_files.compute()
climate_2013 = climate_2013.loc[:, ~climate_2013.columns.str.contains('^Unnamed')]
climate_2013.head()
# Out:
#     fips   elevation  mean_temp  visibility  wind_speed  precipitation  \
# 0  01001   75.264706  64.640000    9.458611    4.721667       0.175994
# 1  01003   12.427907  68.318343         NaN    5.718639       0.000000
# 2  01005   94.311111  65.180769    8.955220    2.894780       0.136304
# 3  01007  162.637500  62.689863    8.563836    3.189041       0.184603
# 4  01009  243.931250  58.804972         NaN    4.011602       0.164530
#
#         fog      rain      snow  hail   thunder  Relative_Humidity  \
# 0  0.122222  0.541667  0.002778   0.0  0.127778          69.636778
# 1  0.000000  0.000000  0.000000   0.0  0.000000                NaN
# 2  0.140110  0.560440  0.019231   0.0  0.208791          70.887648
# 3  0.120548  0.394521  0.008219   0.0  0.134247          69.454756
# 4  0.000000  0.000000  0.000000   0.0  0.000000                NaN
#
#    Heat_Index  PM2.5  Ozone  rurality  SuicideDeathRate
# 0   64.076929   10.5    0.0         3         18.100858
# 1         NaN    8.4    0.0         4         12.785108
# 2   64.730566   10.1    0.0         6          8.066307
# 3   61.923223   10.4    0.0         2          9.685122
# 4         NaN   10.8    0.0         2         13.555654

# %%
climate_2013 = climate_2013[['fips', 'elevation', 'mean_temp', 'visibility', 'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail', 'thunder', 'Relative_Humidity', 'Heat_Index', 'PM2.5', 'Ozone', 'rurality', 'SuicideDeathRate']]

# %%
climate_2013 = climate_2013.dropna()

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
X = climate_2013.iloc[:, 1:-1].values
y = climate_2013.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.17510175, 0.04779652, 0.06106022, 0.13171333, 0.04009093,
#        0.06791702, 0.06777357, 0.04125553, 0.00117801, 0.04880115,
#        0.09276012, 0.06004905, 0.07401489, 0.01847094, 0.07201696])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = climate_2013.columns

# %%
columns = columns[1:-1]
columns = columns.tolist()
columns
# Out:
# ['elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'Relative_Humidity',
#  'Heat_Index',
#  'PM2.5',
#  'Ozone',
#  'rurality']

# %%
len(columns)
# Out:
# 15

# %%
plt.barh(columns, rf.feature_importances_)
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
sorted_idx
# Out:
# array([ 8, 13,  4,  7,  1,  9, 11,  2,  6,  5, 14, 12, 10,  3,  0])

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
rf.feature_importances_[sorted_idx]
# Out:
# array([0.00117801, 0.01847094, 0.04009093, 0.04125553, 0.04779652,
#        0.04880115, 0.06004905, 0.06106022, 0.06777357, 0.06791702,
#        0.07201696, 0.07401489, 0.09276012, 0.13171333, 0.17510175])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
def correlation_matrix(df):
    """
    A function to calculate and plot
    correlation matrix of a DataFrame.
    """
    # Create the matrix
    matrix = df.corr()
    
    # Create cmap
    cmap = sn.diverging_palette(250, 15, s=75, l=40,
                             n=9, center="light", as_cmap=True)
    # Create a mask
    mask = np.triu(np.ones_like(matrix, dtype=bool))
    
    # Make figsize bigger
    fig, ax = plt.subplots(figsize=(16,12))
    
    # Plot the matrix
    _ = sn.heatmap(matrix, mask=mask, center=0, annot=True,
             fmt='.2f', square=True, cmap=cmap, ax=ax)

# %%
correlation_matrix(climate_2013)

# %% [markdown]
# ## Find the economic feature importances

# %%
ur_files = ddf.read_csv('SocialEconomicSuicide/Social_Economic_Suicide_2013.csv', dtype = {'fips': str, 'per_capita_income': float})
social_2013 = ur_files.compute()
social_2013 = social_2013.loc[:, ~social_2013.columns.str.contains('^Unnamed')]
social_2013.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  12033            23441.0               0.181326
# 1  12053            21411.0               0.154438
# 2  12057            27149.0               0.168354
# 3  12091            28600.0               0.133890
# 4  12123            17045.0               0.166555
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.126320              0.060678            0.074376
# 1                       0.140364              0.134934            0.051859
# 2                       0.137730              0.072071            0.069867
# 3                       0.095543              0.077959            0.044763
# 4                       0.245327              0.360582            0.061783
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.270338              0.018355                    0.115251
# 1                0.323604              0.016066                    0.017090
# 2                0.233409              0.028160                    0.177465
# 3                0.217166              0.018648                    0.149217
# 4                0.334827              0.019552                    0.010995
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.147921                           0.074921
# 1                  0.262629                           0.099183
# 2                  0.121268                           0.253345
# 3                  0.140687                           0.092832
# 4                  0.165931                           0.054109
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.212932            0.339823          0.565817
# 1                    0.194779            0.184792          0.561065
# 2                    0.235975            0.469304          0.493081
# 3                    0.223210            0.237259          0.539057
# 4                    0.193910            0.272462          0.803116
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.067804
# 1                                     0.011501
# 2                                     0.016175
# 3                                     0.026214
# 4                                     0.135702
#
#    percent_single_parent_households_CDC                   county  \
# 0                              0.368714      Escambia County, FL
# 1                              0.265226      Hernando County, FL
# 2                              0.312865  Hillsborough County, FL
# 3                              0.272096      Okaloosa County, FL
# 4                              0.377763        Taylor County, FL
#
#    SuicideDeathRate
# 0          9.809788
# 1         13.184974
# 2          6.890796
# 3         13.931098
# 4         12.050784

# %%
social_2013['SuicideDeathRate'].isna().sum()
# Out:
# 200

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
social_2013 = social_2013.dropna(how = 'any')

# %%
social_2013.shape
# Out:
# (3021, 18)

# %%
X = social_2013.iloc[:, 1:-2].values
y = social_2013.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.06770021, 0.04750856, 0.10521841, 0.18075679, 0.04591494,
#        0.03889809, 0.04793075, 0.03988627, 0.05050941, 0.04943591,
#        0.04873611, 0.10892302, 0.08731987, 0.03834583, 0.04291584])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = social_2013.columns
columns = columns[1:-2]
columns = columns.tolist()
columns
# Out:
# ['per_capita_income',
#  'percent_below_poverty',
#  'percent_no_highschool_diploma',
#  'percent_mobile_homes',
#  'percent_no_vehicle',
#  'percent_unemployed_CDC',
#  'percent_overcrowding',
#  'percent_multi_unit_housing',
#  'percent_age_65_and_older',
#  'percent_limited_english_abilities',
#  'percent_age_17_and_younger',
#  'percent_minorities',
#  'percent_disabled',
#  'percent_institutionalized_in_group_quarters',
#  'percent_single_parent_households_CDC']

# %%
social_2013.shape
# Out:
# (3021, 18)

# %%
climate_2013.shape
# Out:
# (2657, 17)

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
correlation_matrix(social_2013)

# %% [markdown]
# ## find the rank of importances of all factors

# %%
df_total = social_2013.merge(climate_2013, on = ['fips', 'SuicideDeathRate'], how = 'left')
df_total = df_total.dropna(how = 'any')
df_total.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  12033            23441.0               0.181326
# 1  12053            21411.0               0.154438
# 2  12057            27149.0               0.168354
# 3  12091            28600.0               0.133890
# 4  12123            17045.0               0.166555
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.126320              0.060678            0.074376
# 1                       0.140364              0.134934            0.051859
# 2                       0.137730              0.072071            0.069867
# 3                       0.095543              0.077959            0.044763
# 4                       0.245327              0.360582            0.061783
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.270338              0.018355                    0.115251
# 1                0.323604              0.016066                    0.017090
# 2                0.233409              0.028160                    0.177465
# 3                0.217166              0.018648                    0.149217
# 4                0.334827              0.019552                    0.010995
#
#    percent_age_65_and_older  ...       fog      rain     snow  hail   thunder  \
# 0                  0.147921  ...  0.019444  0.169444  0.00000   0.0  0.011111
# 1                  0.262629  ...  0.158904  0.372603  0.00000   0.0  0.057534
# 2                  0.121268  ...  0.126027  0.438356  0.00274   0.0  0.000000
# 3                  0.140687  ...  0.180822  0.515068  0.00000   0.0  0.249315
# 4                  0.165931  ...  0.058333  0.225000  0.00000   0.0  0.075000
#
#    Relative_Humidity Heat_Index  PM2.5  Ozone  rurality
# 0          70.183438  68.844233    7.5    1.0       3.0
# 1          74.349482  71.043686    7.0    0.0       2.0
# 2          73.379331  72.667678    6.6    3.0       1.0
# 3          73.545220  66.064625    8.6    0.0       4.0
# 4          66.856350  59.010915    8.0    0.0       6.0
#
# [5 rows x 33 columns]

# %%
col = df_total.columns.values

# %%
col
# Out:
# array(['fips', 'per_capita_income', 'percent_below_poverty',
#        'percent_no_highschool_diploma', 'percent_mobile_homes',
#        'percent_no_vehicle', 'percent_unemployed_CDC',
#        'percent_overcrowding', 'percent_multi_unit_housing',
#        'percent_age_65_and_older', 'percent_limited_english_abilities',
#        'percent_age_17_and_younger', 'percent_minorities',
#        'percent_disabled', 'percent_institutionalized_in_group_quarters',
#        'percent_single_parent_households_CDC', 'county',
#        'SuicideDeathRate', 'elevation', 'mean_temp', 'visibility',
#        'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail',
#        'thunder', 'Relative_Humidity', 'Heat_Index', 'PM2.5', 'Ozone',
#        'rurality'], dtype=object)

# %%
new_col = ['fips', 'county', 'percent_below_poverty',
       'per_capita_income', 'percent_unemployed_CDC',
       'percent_no_highschool_diploma', 'percent_age_65_and_older',
       'percent_age_17_and_younger', 'percent_disabled',
       'percent_single_parent_households_CDC', 'percent_minorities',
       'percent_limited_english_abilities', 'percent_multi_unit_housing',
       'percent_mobile_homes', 'percent_overcrowding',
       'percent_no_vehicle',
       'percent_institutionalized_in_group_quarters', 
       'elevation', 'mean_temp', 'visibility',
       'wind_speed', 'precipitation', 'Relative_Humidity', 'Heat_Index',
       'fog', 'rain', 'snow', 'hail', 'thunder', 'PM2.5',
       'Ozone', 'rurality','SuicideDeathRate']

# %%
df_total = df_total[new_col]

# %%
df_total.shape
# Out:
# (2657, 33)

# %%
df_total.head()
# Out:
#     fips                   county  percent_below_poverty  per_capita_income  \
# 0  12033      Escambia County, FL               0.181326            23441.0
# 1  12053      Hernando County, FL               0.154438            21411.0
# 2  12057  Hillsborough County, FL               0.168354            27149.0
# 3  12091      Okaloosa County, FL               0.133890            28600.0
# 4  12123        Taylor County, FL               0.166555            17045.0
#
#    percent_unemployed_CDC  percent_no_highschool_diploma  \
# 0                0.270338                       0.126320
# 1                0.323604                       0.140364
# 2                0.233409                       0.137730
# 3                0.217166                       0.095543
# 4                0.334827                       0.245327
#
#    percent_age_65_and_older  percent_age_17_and_younger  percent_disabled  \
# 0                  0.147921                    0.212932          0.565817
# 1                  0.262629                    0.194779          0.561065
# 2                  0.121268                    0.235975          0.493081
# 3                  0.140687                    0.223210          0.539057
# 4                  0.165931                    0.193910          0.803116
#
#    percent_single_parent_households_CDC  ...  Heat_Index       fog      rain  \
# 0                              0.368714  ...   68.844233  0.019444  0.169444
# 1                              0.265226  ...   71.043686  0.158904  0.372603
# 2                              0.312865  ...   72.667678  0.126027  0.438356
# 3                              0.272096  ...   66.064625  0.180822  0.515068
# 4                              0.377763  ...   59.010915  0.058333  0.225000
#
#       snow  hail   thunder  PM2.5  Ozone  rurality  SuicideDeathRate
# 0  0.00000   0.0  0.011111    7.5    1.0       3.0          9.809788
# 1  0.00000   0.0  0.057534    7.0    0.0       2.0         13.184974
# 2  0.00274   0.0  0.000000    6.6    3.0       1.0          6.890796
# 3  0.00000   0.0  0.249315    8.6    0.0       4.0         13.931098
# 4  0.00000   0.0  0.075000    8.0    0.0       6.0         12.050784
#
# [5 rows x 33 columns]

# %%
plt.rcParams.update({'figure.figsize': (20.0, 12.0)})
plt.rcParams.update({'font.size': 14})
X = df_total.iloc[:, 2:-1].values
y = df_total.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.02620523, 0.02123545, 0.01809747, 0.03994193, 0.0261679 ,
#        0.01994569, 0.05496271, 0.02030054, 0.08155323, 0.02830892,
#        0.02188174, 0.17246929, 0.01460973, 0.01443403, 0.01600395,
#        0.07561779, 0.02237642, 0.01894692, 0.04149559, 0.01341508,
#        0.06231029, 0.02140655, 0.07357123, 0.01784166, 0.01810523,
#        0.00050827, 0.01933078, 0.01835098, 0.01368096, 0.00692445])

# %%
len(rf.feature_importances_)
# Out:
# 30

# %%
columns = df_total.columns
columns = columns[2:-1]
columns = columns.tolist()
columns
# Out:
# ['percent_below_poverty',
#  'per_capita_income',
#  'percent_unemployed_CDC',
#  'percent_no_highschool_diploma',
#  'percent_age_65_and_older',
#  'percent_age_17_and_younger',
#  'percent_disabled',
#  'percent_single_parent_households_CDC',
#  'percent_minorities',
#  'percent_limited_english_abilities',
#  'percent_multi_unit_housing',
#  'percent_mobile_homes',
#  'percent_overcrowding',
#  'percent_no_vehicle',
#  'percent_institutionalized_in_group_quarters',
#  'elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'Relative_Humidity',
#  'Heat_Index',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'PM2.5',
#  'Ozone',
#  'rurality']

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %% [markdown]
# ## SHAP

# %%
import xgboost
import shap

# %%
X = climate_2013.iloc[:, 1:-1]
y = climate_2013.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"elevation"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"rurality"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"mean_temp"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:,"elevation"],shap_values[:,"rurality"], xmin=500)

# %%
shap.plots.scatter(shap_values[:,"elevation"],shap_values[:,"rurality"], xmin=550)

# %%
shap.plots.scatter(shap_values[:, "PM2.5"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"PM2.5"])

# %%
shap.plots.scatter(shap_values[:, "PM2.5"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"PM2.5"])

# %% [markdown]
# ### social economic factors

# %%
social_2013.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  12033            23441.0               0.181326
# 1  12053            21411.0               0.154438
# 2  12057            27149.0               0.168354
# 3  12091            28600.0               0.133890
# 4  12123            17045.0               0.166555
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.126320              0.060678            0.074376
# 1                       0.140364              0.134934            0.051859
# 2                       0.137730              0.072071            0.069867
# 3                       0.095543              0.077959            0.044763
# 4                       0.245327              0.360582            0.061783
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.270338              0.018355                    0.115251
# 1                0.323604              0.016066                    0.017090
# 2                0.233409              0.028160                    0.177465
# 3                0.217166              0.018648                    0.149217
# 4                0.334827              0.019552                    0.010995
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.147921                           0.074921
# 1                  0.262629                           0.099183
# 2                  0.121268                           0.253345
# 3                  0.140687                           0.092832
# 4                  0.165931                           0.054109
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.212932            0.339823          0.565817
# 1                    0.194779            0.184792          0.561065
# 2                    0.235975            0.469304          0.493081
# 3                    0.223210            0.237259          0.539057
# 4                    0.193910            0.272462          0.803116
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.067804
# 1                                     0.011501
# 2                                     0.016175
# 3                                     0.026214
# 4                                     0.135702
#
#    percent_single_parent_households_CDC                   county  \
# 0                              0.368714      Escambia County, FL
# 1                              0.265226      Hernando County, FL
# 2                              0.312865  Hillsborough County, FL
# 3                              0.272096      Okaloosa County, FL
# 4                              0.377763        Taylor County, FL
#
#    SuicideDeathRate
# 0          9.809788
# 1         13.184974
# 2          6.890796
# 3         13.931098
# 4         12.050784

# %%
X = social_2013.iloc[:, 1:-2]
y = social_2013.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"percent_mobile_homes"], color=shap_values)
