# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dask.dataframe as ddf
from pandas import Series, DataFrame
# %matplotlib inline

# %%
import seaborn as sn
import plotly.express as px

# %%
ur_files = ddf.read_csv('EnvironmentSuicide/Environment_Suicide_2010.csv', dtype = {'fips': str})
climate_2010 = ur_files.compute()
climate_2010 = climate_2010.loc[:, ~climate_2010.columns.str.contains('^Unnamed')]
climate_2010.head()
# Out:
#     fips   elevation  mean_temp  visibility  wind_speed  precipitation  \
# 0  01001   75.264706  64.593699    9.560274    4.142192       0.111501
# 1  01003   12.427907  66.487853         NaN    6.121469       0.000000
# 2  01005   94.311111  64.356164    9.168908    3.013425       0.000000
# 3  01007  162.637500  62.069315    8.890137    3.209041       0.152356
# 4  01009  243.931250  58.765205         NaN    3.766301       0.150329
#
#         fog      rain      snow  hail   thunder  Relative_Humidity  \
# 0  0.123288  0.383562  0.016438   0.0  0.164384          64.818067
# 1  0.000000  0.000000  0.000000   0.0  0.000000                NaN
# 2  0.071233  0.482192  0.063014   0.0  0.194521          63.358387
# 3  0.054795  0.301370  0.027397   0.0  0.139726          64.984348
# 4  0.000000  0.000000  0.000000   0.0  0.000000                NaN
#
#    Heat_Index  PM2.5  Ozone  rurality  SuicideDeathRate
# 0   63.799518   11.1    2.0         3          7.688956
# 1         NaN   10.2    6.0         5          6.722694
# 2   63.469625   11.3    0.0         5          5.266345
# 3   61.030511   11.0    2.0         2          5.439093
# 4         NaN   12.1    7.0         2         12.038791

# %%
climate_2010 = climate_2010[['fips', 'elevation', 'mean_temp', 'visibility', 'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail', 'thunder', 'Relative_Humidity', 'Heat_Index', 'PM2.5', 'Ozone', 'rurality','SuicideDeathRate']]

# %%
climate_2010 = climate_2010.dropna()

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
X = climate_2010.iloc[:, 1:-1].values
y = climate_2010.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.2024106 , 0.12012001, 0.05145631, 0.0686257 , 0.03715771,
#        0.04585375, 0.0497664 , 0.04094494, 0.00730409, 0.07599248,
#        0.08186969, 0.06028897, 0.09450623, 0.04052179, 0.02318131])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = climate_2010.columns

# %%
columns = columns[1:-1]
columns = columns.tolist()
columns
# Out:
# ['elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'Relative_Humidity',
#  'Heat_Index',
#  'PM2.5',
#  'Ozone',
#  'rurality']

# %%
len(columns)
# Out:
# 15

# %%
plt.barh(columns, rf.feature_importances_)
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
sorted_idx
# Out:
# array([ 8, 14,  4, 13,  7,  5,  6,  2, 11,  3,  9, 10, 12,  1,  0])

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
rf.feature_importances_[sorted_idx]
# Out:
# array([0.00730409, 0.02318131, 0.03715771, 0.04052179, 0.04094494,
#        0.04585375, 0.0497664 , 0.05145631, 0.06028897, 0.0686257 ,
#        0.07599248, 0.08186969, 0.09450623, 0.12012001, 0.2024106 ])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
def correlation_matrix(df):
    """
    A function to calculate and plot
    correlation matrix of a DataFrame.
    """
    # Create the matrix
    matrix = df.corr()
    
    # Create cmap
    cmap = sn.diverging_palette(250, 15, s=75, l=40,
                             n=9, center="light", as_cmap=True)
    # Create a mask
    mask = np.triu(np.ones_like(matrix, dtype=bool))
    
    # Make figsize bigger
    fig, ax = plt.subplots(figsize=(16,12))
    
    # Plot the matrix
    _ = sn.heatmap(matrix, mask=mask, center=0, annot=True,
             fmt='.2f', square=True, cmap=cmap, ax=ax)

# %%
correlation_matrix(climate_2010)

# %% [markdown]
# ## Find the economic feature importances

# %%
ur_files = ddf.read_csv('SocialEconomicSuicide/Social_Economic_Suicide_2010.csv', dtype = {'fips': str, 'per_capita_income': float})
social_2010 = ur_files.compute()
social_2010 = social_2010.loc[:, ~social_2010.columns.str.contains('^Unnamed')]
social_2010.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  72083             6417.0               0.594633
# 1  72125             8066.0               0.497617
# 2  72045             6755.0               0.560694
# 3  72029             9852.0               0.425071
# 4  72117             8768.0               0.516478
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.530730              0.001300            0.159590
# 1                       0.376497              0.000000            0.234554
# 2                       0.445225              0.000000            0.206069
# 3                       0.321700              0.000000            0.160223
# 4                       0.432781              0.003158            0.140625
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.378257              0.113138                    0.010056
# 1                0.368010              0.055822                    0.042038
# 2                0.407717              0.093977                    0.010595
# 3                0.340493              0.072559                    0.012545
# 4                0.387784              0.033975                    0.088909
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.127412                           0.953927
# 1                  0.168181                           0.947168
# 2                  0.118086                           0.944393
# 3                  0.113593                           0.951937
# 4                  0.165165                           0.959094
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.256696            0.996160               NaN
# 1                    0.233214            0.987221               NaN
# 2                    0.264959            0.993790               NaN
# 3                    0.276177            0.998876               NaN
# 4                    0.232849            0.919226               NaN
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.015360
# 1                                     0.013640
# 2                                     0.001300
# 3                                     0.002863
# 4                                     0.000132
#
#    percent_single_parent_households_CDC                    county  \
# 0                              0.252896  Las Marías Municipio, PR
# 1                              0.345630  San Germán Municipio, PR
# 2                              0.386628     Comerío Municipio, PR
# 3                              0.358777   Canóvanas Municipio, PR
# 4                              0.410815      Rincón Municipio, PR
#
#    SuicideDeathRate
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
social_2010 = social_2010.dropna(how = 'any')

# %%
social_2010.shape
# Out:
# (801, 18)

# %%
X = social_2010.iloc[:, 1:-2].values
y = social_2010.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.07526706, 0.04807762, 0.0528468 , 0.04666924, 0.0692622 ,
#        0.04768442, 0.09233798, 0.05887647, 0.08283144, 0.06434081,
#        0.06891232, 0.10837201, 0.06838582, 0.05134098, 0.06479483])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = social_2010.columns
columns = columns[1:-2]
columns = columns.tolist()
columns
# Out:
# ['per_capita_income',
#  'percent_below_poverty',
#  'percent_no_highschool_diploma',
#  'percent_mobile_homes',
#  'percent_no_vehicle',
#  'percent_unemployed_CDC',
#  'percent_overcrowding',
#  'percent_multi_unit_housing',
#  'percent_age_65_and_older',
#  'percent_limited_english_abilities',
#  'percent_age_17_and_younger',
#  'percent_minorities',
#  'percent_disabled',
#  'percent_institutionalized_in_group_quarters',
#  'percent_single_parent_households_CDC']

# %%
social_2010.shape
# Out:
# (801, 18)

# %%
climate_2010.shape
# Out:
# (2650, 17)

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
correlation_matrix(social_2010)

# %% [markdown]
# ## find the rank of importances of all factors

# %%
df_total = social_2010.merge(climate_2010, on = ['fips', 'SuicideDeathRate'], how = 'left')
df_total = df_total.dropna(how = 'any')
df_total.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 1  06053            25776.0               0.139343
# 2  06055            34310.0               0.099556
# 3  06057            30727.0               0.089909
# 4  06059            34017.0               0.101477
# 5  06061            35680.0               0.065996
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 1                       0.308630              0.040025            0.063619
# 2                       0.185783              0.047861            0.053559
# 3                       0.060889              0.054706            0.038541
# 4                       0.174462              0.027479            0.046529
# 5                       0.073213              0.022094            0.037792
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 1                0.230747              0.108896                    0.095907
# 2                0.190136              0.061998                    0.079439
# 3                0.217866              0.025451                    0.027870
# 4                0.193313              0.091292                    0.184261
# 5                0.190890              0.016964                    0.064100
#
#    percent_age_65_and_older  ...       fog      rain      snow  hail  \
# 1                  0.104446  ...  0.080189  0.250000  0.000000   0.0
# 2                  0.149354  ...  0.153425  0.254795  0.005479   0.0
# 3                  0.185800  ...  0.317808  0.265753  0.232877   0.0
# 4                  0.111910  ...  0.046575  0.186301  0.000000   0.0
# 5                  0.147900  ...  0.317808  0.265753  0.232877   0.0
#
#     thunder  Relative_Humidity Heat_Index  PM2.5  Ozone  rurality
# 1  0.000000          74.175197  53.834630    4.5    0.0       3.0
# 2  0.000000          75.186155  54.219256    8.1    2.0       4.0
# 3  0.000000          49.011733  47.202456    5.7   22.0       5.0
# 4  0.016438          60.491504  62.646251   10.2    6.0       1.0
# 5  0.000000          49.011733  47.202456    6.6   28.0       2.0
#
# [5 rows x 33 columns]

# %%
col = df_total.columns.values

# %%
col
# Out:
# array(['fips', 'per_capita_income', 'percent_below_poverty',
#        'percent_no_highschool_diploma', 'percent_mobile_homes',
#        'percent_no_vehicle', 'percent_unemployed_CDC',
#        'percent_overcrowding', 'percent_multi_unit_housing',
#        'percent_age_65_and_older', 'percent_limited_english_abilities',
#        'percent_age_17_and_younger', 'percent_minorities',
#        'percent_disabled', 'percent_institutionalized_in_group_quarters',
#        'percent_single_parent_households_CDC', 'county',
#        'SuicideDeathRate', 'elevation', 'mean_temp', 'visibility',
#        'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail',
#        'thunder', 'Relative_Humidity', 'Heat_Index', 'PM2.5', 'Ozone',
#        'rurality'], dtype=object)

# %%
new_col = ['fips', 'county', 'percent_below_poverty',
       'per_capita_income', 'percent_unemployed_CDC',
       'percent_no_highschool_diploma', 'percent_age_65_and_older',
       'percent_age_17_and_younger', 'percent_disabled',
       'percent_single_parent_households_CDC', 'percent_minorities',
       'percent_limited_english_abilities', 'percent_multi_unit_housing',
       'percent_mobile_homes', 'percent_overcrowding',
       'percent_no_vehicle',
       'percent_institutionalized_in_group_quarters', 
       'elevation', 'mean_temp', 'visibility',
       'wind_speed', 'precipitation', 'Relative_Humidity', 'Heat_Index',
       'fog', 'rain', 'snow', 'hail', 'thunder', 'PM2.5',
       'Ozone', 'rurality','SuicideDeathRate']

# %%
df_total = df_total[new_col]

# %%
df_total.shape
# Out:
# (734, 33)

# %%
df_total.head()
# Out:
#     fips               county  percent_below_poverty  per_capita_income  \
# 1  06053  Monterey County, CA               0.139343            25776.0
# 2  06055      Napa County, CA               0.099556            34310.0
# 3  06057    Nevada County, CA               0.089909            30727.0
# 4  06059    Orange County, CA               0.101477            34017.0
# 5  06061    Placer County, CA               0.065996            35680.0
#
#    percent_unemployed_CDC  percent_no_highschool_diploma  \
# 1                0.230747                       0.308630
# 2                0.190136                       0.185783
# 3                0.217866                       0.060889
# 4                0.193313                       0.174462
# 5                0.190890                       0.073213
#
#    percent_age_65_and_older  percent_age_17_and_younger  percent_disabled  \
# 1                  0.104446                    0.268728          0.327430
# 2                  0.149354                    0.232971          0.502156
# 3                  0.185800                    0.200466          0.464468
# 4                  0.111910                    0.249905          0.411694
# 5                  0.147900                    0.248302          0.463303
#
#    percent_single_parent_households_CDC  ...  Heat_Index       fog      rain  \
# 1                              0.212356  ...   53.834630  0.080189  0.250000
# 2                              0.187902  ...   54.219256  0.153425  0.254795
# 3                              0.233320  ...   47.202456  0.317808  0.265753
# 4                              0.188985  ...   62.646251  0.046575  0.186301
# 5                              0.167631  ...   47.202456  0.317808  0.265753
#
#        snow  hail   thunder  PM2.5  Ozone  rurality  SuicideDeathRate
# 1  0.000000   0.0  0.000000    4.5    0.0       3.0          6.505131
# 2  0.005479   0.0  0.000000    8.1    2.0       4.0          7.326866
# 3  0.232877   0.0  0.000000    5.7   22.0       5.0         10.262358
# 4  0.000000   0.0  0.016438   10.2    6.0       1.0          6.145706
# 5  0.232877   0.0  0.000000    6.6   28.0       2.0          8.897001
#
# [5 rows x 33 columns]

# %%
plt.rcParams.update({'figure.figsize': (20.0, 12.0)})
plt.rcParams.update({'font.size': 14})
X = df_total.iloc[:, 2:-1].values
y = df_total.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.04748713, 0.03759364, 0.06988741, 0.01839544, 0.05287424,
#        0.02900419, 0.03851258, 0.03815659, 0.06407142, 0.03470482,
#        0.0241902 , 0.0184135 , 0.06798134, 0.01994291, 0.02113474,
#        0.05584536, 0.02969164, 0.02126403, 0.02725594, 0.01855283,
#        0.02615007, 0.02745502, 0.02249605, 0.02376682, 0.02335539,
#        0.00325038, 0.02602707, 0.06076802, 0.01895113, 0.03282008])

# %%
len(rf.feature_importances_)
# Out:
# 30

# %%
columns = df_total.columns
columns = columns[2:-1]
columns = columns.tolist()
columns
# Out:
# ['percent_below_poverty',
#  'per_capita_income',
#  'percent_unemployed_CDC',
#  'percent_no_highschool_diploma',
#  'percent_age_65_and_older',
#  'percent_age_17_and_younger',
#  'percent_disabled',
#  'percent_single_parent_households_CDC',
#  'percent_minorities',
#  'percent_limited_english_abilities',
#  'percent_multi_unit_housing',
#  'percent_mobile_homes',
#  'percent_overcrowding',
#  'percent_no_vehicle',
#  'percent_institutionalized_in_group_quarters',
#  'elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'Relative_Humidity',
#  'Heat_Index',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'PM2.5',
#  'Ozone',
#  'rurality']

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %% [markdown]
# ## SHAP

# %%
import xgboost
import shap

# %%
X = climate_2010.iloc[:, 1:-1]
y = climate_2010.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"elevation"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"PM2.5"])

# %%
shap.plots.scatter(shap_values[:, "PM2.5"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "PM2.5"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"PM2.5"])

# %%
shap.plots.scatter(shap_values[:,"rurality"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"mean_temp"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:,"elevation"],shap_values[:,"rurality"], xmin=500)

# %%
shap.plots.scatter(shap_values[:,"elevation"],shap_values[:,"rurality"], xmin=600)

# %% [markdown]
# ### social economic factors

# %%
social_2010.head()
# Out:
#      fips  per_capita_income  percent_below_poverty  \
# 15  06047            18041.0               0.218217
# 18  06053            25776.0               0.139343
# 19  06055            34310.0               0.099556
# 20  06057            30727.0               0.089909
# 21  06059            34017.0               0.101477
#
#     percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 15                       0.349936              0.050807            0.079010
# 18                       0.308630              0.040025            0.063619
# 19                       0.185783              0.047861            0.053559
# 20                       0.060889              0.054706            0.038541
# 21                       0.174462              0.027479            0.046529
#
#     percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 15                0.282026              0.087707                    0.041257
# 18                0.230747              0.108896                    0.095907
# 19                0.190136              0.061998                    0.079439
# 20                0.217866              0.025451                    0.027870
# 21                0.193313              0.091292                    0.184261
#
#     percent_age_65_and_older  percent_limited_english_abilities  \
# 15                  0.090292                           0.502396
# 18                  0.104446                           0.503165
# 19                  0.149354                           0.324041
# 20                  0.185800                           0.063934
# 21                  0.111910                           0.426643
#
#     percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 15                    0.321553            0.669297          0.668948
# 18                    0.268728            0.657528          0.327430
# 19                    0.232971            0.417319          0.502156
# 20                    0.200466            0.127360          0.464468
# 21                    0.249905            0.544835          0.411694
#
#     percent_institutionalized_in_group_quarters  \
# 15                                     0.014152
# 18                                     0.042900
# 19                                     0.040805
# 20                                     0.008077
# 21                                     0.013705
#
#     percent_single_parent_households_CDC               county  \
# 15                              0.204076    Merced County, CA
# 18                              0.212356  Monterey County, CA
# 19                              0.187902      Napa County, CA
# 20                              0.233320    Nevada County, CA
# 21                              0.188985    Orange County, CA
#
#     SuicideDeathRate
# 15          7.036940
# 18          6.505131
# 19          7.326866
# 20         10.262358
# 21          6.145706

# %%
X = social_2010.iloc[:, 1:-2]
y = social_2010.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"percent_mobile_homes"], color=shap_values)
