# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dask.dataframe as ddf
from pandas import Series, DataFrame
# %matplotlib inline

# %%
import seaborn as sn
import plotly.express as px

# %%
ur_files = ddf.read_csv('EnvironmentSuicide/Environment_Suicide_2019.csv', dtype = {'fips': str})
climate_2019 = ur_files.compute()
climate_2019 = climate_2019.loc[:, ~climate_2019.columns.str.contains('^Unnamed')]
climate_2019.head()
# Out:
#     fips   elevation  mean_temp  visibility  wind_speed  precipitation  \
# 0  01001   75.264706  66.574028    9.576668    4.017496       0.134878
# 1  01003   12.427907  68.978591    9.251672    3.789960       0.063868
# 2  01005   94.311111  58.450971    9.010767    3.505694       0.143485
# 3  01007  162.637500  64.887816    9.502343    4.396241       0.139342
# 4  01009  243.931250  62.892951    9.413237    4.117425       0.121650
#
#          fog        rain      snow    hail    thunder  Relative_Humidity  \
# 0  24.058824  136.294118  0.176471  0.0000  36.176471          69.510809
# 1  18.441860   39.627907  0.000000  0.0000  13.976744          76.607434
# 2  13.888889   45.555556  0.000000  0.0000   6.000000          68.853344
# 3  17.750000  106.250000  1.000000  0.0000  31.750000          70.428637
# 4  14.312500  103.062500  2.187500  0.3125  23.187500          67.067604
#
#    Heat_Index  rurality  SuicideDeathRate
# 0   67.764757       3.0          5.099510
# 1   67.310117       4.0         11.466733
# 2   56.133099       6.0         10.193062
# 3   64.891663       2.0          4.521543
# 4   63.131224       2.0          3.943577

# %%
climate_2019 = climate_2019[['fips', 'elevation', 'mean_temp', 'visibility', 'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail', 'thunder', 'Relative_Humidity', 'Heat_Index','rurality','SuicideDeathRate']]

# %%
climate_2019 = climate_2019.dropna()

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
X = climate_2019.iloc[:, 1:-1].values
y = climate_2019.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.23198134, 0.07441663, 0.07175556, 0.06829324, 0.05620552,
#        0.07382686, 0.06035063, 0.09005892, 0.00442643, 0.06303241,
#        0.08450895, 0.09069315, 0.03045036])

# %%
len(rf.feature_importances_)
# Out:
# 13

# %%
columns = climate_2019.columns

# %%
columns = columns[1:-1]
columns = columns.tolist()
columns
# Out:
# ['elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'Relative_Humidity',
#  'Heat_Index',
#  'rurality']

# %%
len(columns)
# Out:
# 13

# %%
plt.barh(columns, rf.feature_importances_)
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
sorted_idx
# Out:
# array([ 8, 12,  4,  6,  9,  3,  2,  5,  1, 10,  7, 11,  0])

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
rf.feature_importances_[sorted_idx]
# Out:
# array([0.00442643, 0.03045036, 0.05620552, 0.06035063, 0.06303241,
#        0.06829324, 0.07175556, 0.07382686, 0.07441663, 0.08450895,
#        0.09005892, 0.09069315, 0.23198134])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
def correlation_matrix(df):
    """
    A function to calculate and plot
    correlation matrix of a DataFrame.
    """
    # Create the matrix
    matrix = df.corr()
    
    # Create cmap
    cmap = sn.diverging_palette(250, 15, s=75, l=40,
                             n=9, center="light", as_cmap=True)
    # Create a mask
    mask = np.triu(np.ones_like(matrix, dtype=bool))
    
    # Make figsize bigger
    fig, ax = plt.subplots(figsize=(16,12))
    
    # Plot the matrix
    _ = sn.heatmap(matrix, mask=mask, center=0, annot=True,
             fmt='.2f', square=True, cmap=cmap, ax=ax)

# %%
correlation_matrix(climate_2019)

# %% [markdown]
# ## Find the economic feature importances

# %%
ur_files = ddf.read_csv('SocialEconomicSuicide/Social_Economic_Suicide_2019.csv', dtype = {'fips': str, 'per_capita_income': float})
social_2019 = ur_files.compute()
social_2019 = social_2019.loc[:, ~social_2019.columns.str.contains('^Unnamed')]
social_2019.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  17051            23194.0               0.172299
# 1  17107            27546.0               0.092998
# 2  17165            25342.0               0.210625
# 3  17097            45766.0               0.079334
# 4  17127            23539.0               0.167481
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.168072              0.121243            0.041101
# 1                       0.116134              0.031129            0.065666
# 2                       0.138024              0.127362            0.087345
# 3                       0.100785              0.016933            0.050483
# 4                       0.140006              0.186591            0.074373
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.261166              0.018095                    0.016103
# 1                0.246532              0.006298                    0.038091
# 2                0.232927              0.019755                    0.031335
# 3                0.170007              0.022895                    0.116606
# 4                0.241649              0.031089                    0.023665
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.188175                           0.042198
# 1                  0.180119                           0.042769
# 2                  0.199425                           0.030939
# 3                  0.137338                           0.264006
# 4                  0.208313                           0.023607
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.206538            0.078692          0.592117
# 1                    0.193325            0.136331          0.531459
# 2                    0.216554            0.084896          0.784262
# 3                    0.244551            0.383638          0.386471
# 4                    0.225332            0.117589          0.661347
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.077487
# 1                                     0.141606
# 2                                     0.020588
# 3                                     0.025938
# 4                                     0.023419
#
#    percent_single_parent_households_CDC              county  SuicideDeathRate
# 0                              0.245957  Fayette County, IL         10.378423
# 1                              0.146590    Logan County, IL          7.354517
# 2                              0.279398   Saline County, IL          8.288483
# 3                              0.183018     Lake County, IL          6.135565
# 4                              0.209114   Massac County, IL               NaN

# %%
social_2019['SuicideDeathRate'].isna().sum()
# Out:
# 153

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
social_2019 = social_2019.dropna(how = 'any')

# %%
social_2019.shape
# Out:
# (3066, 18)

# %%
X = social_2019.iloc[:, 1:-2].values
y = social_2019.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.0561254 , 0.05923527, 0.08285946, 0.06294891, 0.05124738,
#        0.05594457, 0.06853076, 0.0471106 , 0.08849086, 0.05718172,
#        0.08311159, 0.08141564, 0.05326946, 0.05403586, 0.09849253])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = social_2019.columns
columns = columns[1:-2]
columns = columns.tolist()
columns
# Out:
# ['per_capita_income',
#  'percent_below_poverty',
#  'percent_no_highschool_diploma',
#  'percent_mobile_homes',
#  'percent_no_vehicle',
#  'percent_unemployed_CDC',
#  'percent_overcrowding',
#  'percent_multi_unit_housing',
#  'percent_age_65_and_older',
#  'percent_limited_english_abilities',
#  'percent_age_17_and_younger',
#  'percent_minorities',
#  'percent_disabled',
#  'percent_institutionalized_in_group_quarters',
#  'percent_single_parent_households_CDC']

# %%
social_2019.shape
# Out:
# (3066, 18)

# %%
climate_2019.shape
# Out:
# (2913, 15)

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
correlation_matrix(social_2019)

# %% [markdown]
# ## find the rank of importances of all factors

# %%
df_total = social_2019.merge(climate_2019, on = ['fips', 'SuicideDeathRate'], how = 'left')
df_total = df_total.dropna(how = 'any')
df_total.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  17051            23194.0               0.172299
# 1  17107            27546.0               0.092998
# 2  17165            25342.0               0.210625
# 3  17097            45766.0               0.079334
# 4  17017            26992.0               0.147758
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.168072              0.121243            0.041101
# 1                       0.116134              0.031129            0.065666
# 2                       0.138024              0.127362            0.087345
# 3                       0.100785              0.016933            0.050483
# 4                       0.171234              0.098109            0.058894
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.261166              0.018095                    0.016103
# 1                0.246532              0.006298                    0.038091
# 2                0.232927              0.019755                    0.031335
# 3                0.170007              0.022895                    0.116606
# 4                0.188659              0.018243                    0.028341
#
#    percent_age_65_and_older  ...  wind_speed  precipitation        fog  \
# 0                  0.188175  ...    5.668848       0.092116  23.714286
# 1                  0.180119  ...    4.868681       0.082689  20.000000
# 2                  0.199425  ...    4.976438       0.127861  34.000000
# 3                  0.137338  ...    7.551244       0.115030  32.622642
# 4                  0.172577  ...    7.190411       0.108049  24.000000
#
#          rain       snow  hail    thunder  Relative_Humidity  Heat_Index  \
# 0  148.857143  36.142857   0.0  49.714286          73.041217   54.531103
# 1  152.000000  22.000000   0.0  42.000000          76.314146   51.980329
# 2  148.000000  27.000000   0.0  38.000000          75.751055   55.565829
# 3  109.698113  42.459119   0.0  27.238994          68.724362   46.826146
# 4  142.000000  35.000000   0.0  49.000000          75.155561   50.923799
#
#    rurality
# 0       6.0
# 1       5.0
# 2       6.0
# 3       2.0
# 4       6.0
#
# [5 rows x 31 columns]

# %%
col = df_total.columns.values

# %%
col
# Out:
# array(['fips', 'per_capita_income', 'percent_below_poverty',
#        'percent_no_highschool_diploma', 'percent_mobile_homes',
#        'percent_no_vehicle', 'percent_unemployed_CDC',
#        'percent_overcrowding', 'percent_multi_unit_housing',
#        'percent_age_65_and_older', 'percent_limited_english_abilities',
#        'percent_age_17_and_younger', 'percent_minorities',
#        'percent_disabled', 'percent_institutionalized_in_group_quarters',
#        'percent_single_parent_households_CDC', 'county',
#        'SuicideDeathRate', 'elevation', 'mean_temp', 'visibility',
#        'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail',
#        'thunder', 'Relative_Humidity', 'Heat_Index', 'rurality'],
#       dtype=object)

# %%
new_col = ['fips', 'county', 'percent_below_poverty',
       'per_capita_income', 'percent_unemployed_CDC',
       'percent_no_highschool_diploma', 'percent_age_65_and_older',
       'percent_age_17_and_younger', 'percent_disabled',
       'percent_single_parent_households_CDC', 'percent_minorities',
       'percent_limited_english_abilities', 'percent_multi_unit_housing',
       'percent_mobile_homes', 'percent_overcrowding',
       'percent_no_vehicle',
       'percent_institutionalized_in_group_quarters', 
       'elevation', 'mean_temp', 'visibility',
       'wind_speed', 'precipitation', 'Relative_Humidity', 'Heat_Index',
       'fog', 'rain', 'snow', 'hail', 'thunder','rurality','SuicideDeathRate']

# %%
df_total = df_total[new_col]

# %%
df_total.shape
# Out:
# (2912, 31)

# %%
df_total.head()
# Out:
#     fips              county  percent_below_poverty  per_capita_income  \
# 0  17051  Fayette County, IL               0.172299            23194.0
# 1  17107    Logan County, IL               0.092998            27546.0
# 2  17165   Saline County, IL               0.210625            25342.0
# 3  17097     Lake County, IL               0.079334            45766.0
# 4  17017     Cass County, IL               0.147758            26992.0
#
#    percent_unemployed_CDC  percent_no_highschool_diploma  \
# 0                0.261166                       0.168072
# 1                0.246532                       0.116134
# 2                0.232927                       0.138024
# 3                0.170007                       0.100785
# 4                0.188659                       0.171234
#
#    percent_age_65_and_older  percent_age_17_and_younger  percent_disabled  \
# 0                  0.188175                    0.206538          0.592117
# 1                  0.180119                    0.193325          0.531459
# 2                  0.199425                    0.216554          0.784262
# 3                  0.137338                    0.244551          0.386471
# 4                  0.172577                    0.243576          0.550711
#
#    percent_single_parent_households_CDC  ...  precipitation  \
# 0                              0.245957  ...       0.092116
# 1                              0.146590  ...       0.082689
# 2                              0.279398  ...       0.127861
# 3                              0.183018  ...       0.115030
# 4                              0.242195  ...       0.108049
#
#    Relative_Humidity  Heat_Index        fog        rain       snow  hail  \
# 0          73.041217   54.531103  23.714286  148.857143  36.142857   0.0
# 1          76.314146   51.980329  20.000000  152.000000  22.000000   0.0
# 2          75.751055   55.565829  34.000000  148.000000  27.000000   0.0
# 3          68.724362   46.826146  32.622642  109.698113  42.459119   0.0
# 4          75.155561   50.923799  24.000000  142.000000  35.000000   0.0
#
#      thunder  rurality  SuicideDeathRate
# 0  49.714286       6.0         10.378423
# 1  42.000000       5.0          7.354517
# 2  38.000000       6.0          8.288483
# 3  27.238994       2.0          6.135565
# 4  49.000000       6.0          5.119070
#
# [5 rows x 31 columns]

# %%
plt.rcParams.update({'figure.figsize': (20.0, 12.0)})
plt.rcParams.update({'font.size': 14})
X = df_total.iloc[:, 2:-1].values
y = df_total.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.02636792, 0.02824082, 0.02181883, 0.02005806, 0.03587071,
#        0.02484874, 0.02448345, 0.02108627, 0.03579504, 0.02526729,
#        0.02022285, 0.02861979, 0.03362923, 0.02377133, 0.01981762,
#        0.20130755, 0.04854753, 0.03588751, 0.03582276, 0.0260192 ,
#        0.04285546, 0.06117126, 0.03463641, 0.03004853, 0.05101213,
#        0.00211509, 0.02926083, 0.01141777])

# %%
len(rf.feature_importances_)
# Out:
# 28

# %%
columns = df_total.columns
columns = columns[2:-1]
columns = columns.tolist()
columns
# Out:
# ['percent_below_poverty',
#  'per_capita_income',
#  'percent_unemployed_CDC',
#  'percent_no_highschool_diploma',
#  'percent_age_65_and_older',
#  'percent_age_17_and_younger',
#  'percent_disabled',
#  'percent_single_parent_households_CDC',
#  'percent_minorities',
#  'percent_limited_english_abilities',
#  'percent_multi_unit_housing',
#  'percent_mobile_homes',
#  'percent_overcrowding',
#  'percent_no_vehicle',
#  'percent_institutionalized_in_group_quarters',
#  'elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'Relative_Humidity',
#  'Heat_Index',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'rurality']

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %% [markdown]
# ## SHAP

# %%
import xgboost
import shap

# %%
climate_2019.head()
# Out:
#     fips   elevation  mean_temp  visibility  wind_speed  precipitation  \
# 0  01001   75.264706  66.574028    9.576668    4.017496       0.134878
# 1  01003   12.427907  68.978591    9.251672    3.789960       0.063868
# 2  01005   94.311111  58.450971    9.010767    3.505694       0.143485
# 3  01007  162.637500  64.887816    9.502343    4.396241       0.139342
# 4  01009  243.931250  62.892951    9.413237    4.117425       0.121650
#
#          fog        rain      snow    hail    thunder  Relative_Humidity  \
# 0  24.058824  136.294118  0.176471  0.0000  36.176471          69.510809
# 1  18.441860   39.627907  0.000000  0.0000  13.976744          76.607434
# 2  13.888889   45.555556  0.000000  0.0000   6.000000          68.853344
# 3  17.750000  106.250000  1.000000  0.0000  31.750000          70.428637
# 4  14.312500  103.062500  2.187500  0.3125  23.187500          67.067604
#
#    Heat_Index  rurality  SuicideDeathRate
# 0   67.764757       3.0          5.099510
# 1   67.310117       4.0         11.466733
# 2   56.133099       6.0         10.193062
# 3   64.891663       2.0          4.521543
# 4   63.131224       2.0          3.943577

# %%
X = climate_2019.iloc[:, 1:-1]
y = climate_2019.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"elevation"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"rurality"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:,"elevation"],shap_values[:,"rurality"], xmin=500)

# %% [markdown]
# ### social economic factors

# %%
social_2019.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  17051            23194.0               0.172299
# 1  17107            27546.0               0.092998
# 2  17165            25342.0               0.210625
# 3  17097            45766.0               0.079334
# 5  17017            26992.0               0.147758
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.168072              0.121243            0.041101
# 1                       0.116134              0.031129            0.065666
# 2                       0.138024              0.127362            0.087345
# 3                       0.100785              0.016933            0.050483
# 5                       0.171234              0.098109            0.058894
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.261166              0.018095                    0.016103
# 1                0.246532              0.006298                    0.038091
# 2                0.232927              0.019755                    0.031335
# 3                0.170007              0.022895                    0.116606
# 5                0.188659              0.018243                    0.028341
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.188175                           0.042198
# 1                  0.180119                           0.042769
# 2                  0.199425                           0.030939
# 3                  0.137338                           0.264006
# 5                  0.172577                           0.164598
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.206538            0.078692          0.592117
# 1                    0.193325            0.136331          0.531459
# 2                    0.216554            0.084896          0.784262
# 3                    0.244551            0.383638          0.386471
# 5                    0.243576            0.245177          0.550711
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.077487
# 1                                     0.141606
# 2                                     0.020588
# 3                                     0.025938
# 5                                     0.013608
#
#    percent_single_parent_households_CDC              county  SuicideDeathRate
# 0                              0.245957  Fayette County, IL         10.378423
# 1                              0.146590    Logan County, IL          7.354517
# 2                              0.279398   Saline County, IL          8.288483
# 3                              0.183018     Lake County, IL          6.135565
# 5                              0.242195     Cass County, IL          5.119070

# %%
X = social_2019.iloc[:, 1:-2]
y = social_2019.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"percent_mobile_homes"], color=shap_values)
