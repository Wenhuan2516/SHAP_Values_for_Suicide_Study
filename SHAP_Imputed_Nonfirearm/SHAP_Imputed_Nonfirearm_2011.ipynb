# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dask.dataframe as ddf
from pandas import Series, DataFrame
# %matplotlib inline

# %%
import seaborn as sn
import plotly.express as px

# %%
ur_files = ddf.read_csv('EnvironmentSuicide/Environment_Suicide_2011.csv', dtype = {'fips': str})
climate_2011 = ur_files.compute()
climate_2011 = climate_2011.loc[:, ~climate_2011.columns.str.contains('^Unnamed')]
climate_2011.head()
# Out:
#     fips   elevation  mean_temp  visibility  wind_speed  precipitation  \
# 0  01001   75.264706  65.621429    9.297253    4.252198       0.126039
# 1  01003   12.427907  68.232022         NaN    6.284270       0.000000
# 2  01005   94.311111  66.181319    9.162953    3.095055       0.075809
# 3  01007  162.637500  63.414521    9.024384    3.372055       0.128986
# 4  01009  243.931250  60.076986         NaN    4.146575       0.157205
#
#         fog      rain      snow  hail   thunder  Relative_Humidity  \
# 0  0.159341  0.450549  0.010989   0.0  0.151099          67.286664
# 1  0.000000  0.000000  0.000000   0.0  0.000000                NaN
# 2  0.101648  0.609890  0.057692   0.0  0.208791          62.049123
# 3  0.052055  0.301370  0.013699   0.0  0.134247          67.718741
# 4  0.000000  0.000000  0.000000   0.0  0.000000                NaN
#
#    Heat_Index  PM2.5  Ozone  rurality  SuicideDeathRate
# 0   65.046045   11.1    1.0         3          4.704590
# 1         NaN   10.0    9.0         5          5.507895
# 2   65.415759   10.8    1.0         5          7.619998
# 3   62.638753   11.0    6.0         2          4.704590
# 4         NaN   11.6    7.0         2         12.084191

# %%
climate_2011 = climate_2011[['fips', 'elevation', 'mean_temp', 'visibility', 'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail', 'thunder', 'Relative_Humidity', 'Heat_Index', 'PM2.5', 'Ozone', 'rurality','SuicideDeathRate']]

# %%
climate_2011 = climate_2011.dropna()

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
X = climate_2011.iloc[:, 1:-1].values
y = climate_2011.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.15708286, 0.07036499, 0.06645029, 0.06781746, 0.0345009 ,
#        0.05355996, 0.06079051, 0.06287108, 0.00389848, 0.06431826,
#        0.07487644, 0.11750987, 0.09885953, 0.0390996 , 0.02799977])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = climate_2011.columns

# %%
columns = columns[1:-1]
columns = columns.tolist()
columns
# Out:
# ['elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'Relative_Humidity',
#  'Heat_Index',
#  'PM2.5',
#  'Ozone',
#  'rurality']

# %%
len(columns)
# Out:
# 15

# %%
plt.barh(columns, rf.feature_importances_)
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
sorted_idx
# Out:
# array([ 8, 14,  4, 13,  5,  6,  7,  9,  2,  3,  1, 10, 12, 11,  0])

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
rf.feature_importances_[sorted_idx]
# Out:
# array([0.00389848, 0.02799977, 0.0345009 , 0.0390996 , 0.05355996,
#        0.06079051, 0.06287108, 0.06431826, 0.06645029, 0.06781746,
#        0.07036499, 0.07487644, 0.09885953, 0.11750987, 0.15708286])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
def correlation_matrix(df):
    """
    A function to calculate and plot
    correlation matrix of a DataFrame.
    """
    # Create the matrix
    matrix = df.corr()
    
    # Create cmap
    cmap = sn.diverging_palette(250, 15, s=75, l=40,
                             n=9, center="light", as_cmap=True)
    # Create a mask
    mask = np.triu(np.ones_like(matrix, dtype=bool))
    
    # Make figsize bigger
    fig, ax = plt.subplots(figsize=(16,12))
    
    # Plot the matrix
    _ = sn.heatmap(matrix, mask=mask, center=0, annot=True,
             fmt='.2f', square=True, cmap=cmap, ax=ax)

# %%
correlation_matrix(climate_2011)

# %% [markdown]
# ## Find the economic feature importances

# %%
ur_files = ddf.read_csv('SocialEconomicSuicide/Social_Economic_Suicide_2011.csv', dtype = {'fips': str, 'per_capita_income': float})
social_2011 = ur_files.compute()
social_2011 = social_2011.loc[:, ~social_2011.columns.str.contains('^Unnamed')]
social_2011.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  56037            31125.0               0.092924
# 1  56031            25280.0               0.118223
# 2  56033            27805.0               0.081668
# 3  56003            25452.0               0.091598
# 4  56011            25653.0               0.077823
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.096559              0.242061            0.033073
# 1                       0.082689              0.142990            0.044694
# 2                       0.062251              0.093855            0.046951
# 3                       0.106353              0.139167            0.020382
# 4                       0.081313              0.257348            0.005874
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.181376              0.030211                    0.064059
# 1                0.177694              0.012887                    0.017149
# 2                0.150884              0.023557                    0.032139
# 3                0.190996              0.019297                    0.009142
# 4                0.190272              0.022806                    0.004210
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.082661                           0.089963
# 1                  0.203433                           0.036298
# 2                  0.154333                           0.044119
# 3                  0.177703                           0.057029
# 4                  0.159688                           0.023684
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.269814            0.185646               NaN
# 1                    0.210575            0.072342               NaN
# 2                    0.221063            0.071391               NaN
# 3                    0.258201            0.104908               NaN
# 4                    0.234768            0.023968               NaN
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.015550
# 1                                     0.011519
# 2                                     0.029538
# 3                                     0.014801
# 4                                     0.012561
#
#    percent_single_parent_households_CDC                 county  \
# 0                              0.162539  Sweetwater County, WY
# 1                              0.287199      Platte County, WY
# 2                              0.263380    Sheridan County, WY
# 3                              0.128490    Big Horn County, WY
# 4                              0.159402       Crook County, WY
#
#    SuicideDeathRate
# 0         10.676988
# 1         16.184722
# 2          9.329042
# 3          9.329042
# 4          9.329042

# %%
social_2011['SuicideDeathRate'].isna().sum()
# Out:
# 279

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
social_2011 = social_2011.dropna(how = 'any')

# %%
social_2011.shape
# Out:
# (796, 18)

# %%
X = social_2011.iloc[:, 1:-2].values
y = social_2011.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.06562592, 0.0315446 , 0.04632013, 0.06328672, 0.04250866,
#        0.04951134, 0.06969301, 0.08866367, 0.13348245, 0.05793827,
#        0.0580113 , 0.13263225, 0.07371129, 0.03465102, 0.05241936])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = social_2011.columns
columns = columns[1:-2]
columns = columns.tolist()
columns
# Out:
# ['per_capita_income',
#  'percent_below_poverty',
#  'percent_no_highschool_diploma',
#  'percent_mobile_homes',
#  'percent_no_vehicle',
#  'percent_unemployed_CDC',
#  'percent_overcrowding',
#  'percent_multi_unit_housing',
#  'percent_age_65_and_older',
#  'percent_limited_english_abilities',
#  'percent_age_17_and_younger',
#  'percent_minorities',
#  'percent_disabled',
#  'percent_institutionalized_in_group_quarters',
#  'percent_single_parent_households_CDC']

# %%
social_2011.shape
# Out:
# (796, 18)

# %%
climate_2011.shape
# Out:
# (2583, 17)

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
correlation_matrix(social_2011)

# %% [markdown]
# ## find the rank of importances of all factors

# %%
df_total = social_2011.merge(climate_2011, on = ['fips', 'SuicideDeathRate'], how = 'left')
df_total = df_total.dropna(how = 'any')
df_total.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  36119            48306.0               0.088929
# 3  36109            26199.0               0.203616
# 4  36113            28939.0               0.106980
# 6  36055            27712.0               0.144338
# 7  36065            24459.0               0.151475
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.131234              0.000916            0.144683
# 3                       0.077040              0.082709            0.136046
# 4                       0.098109              0.070767            0.067906
# 6                       0.119694              0.006284            0.113960
# 7                       0.143589              0.060457            0.109580
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.189093              0.042072                    0.267763
# 3                0.303702              0.013444                    0.118258
# 4                0.195584              0.009439                    0.048014
# 6                0.215928              0.011992                    0.093280
# 7                0.226020              0.013924                    0.065988
#
#    percent_age_65_and_older  ...       fog      rain      snow     hail  \
# 0                  0.145379  ...  0.172603  0.383562  0.079452  0.00000
# 3                  0.107064  ...  0.164384  0.449315  0.241096  0.00000
# 4                  0.167744  ...  0.268493  0.378082  0.147945  0.00000
# 6                  0.138034  ...  0.095890  0.468493  0.252055  0.00274
# 7                  0.161855  ...  0.200000  0.449315  0.238356  0.00000
#
#     thunder  Relative_Humidity Heat_Index  PM2.5  Ozone  rurality
# 0  0.073973          66.603371  51.191235    9.4    5.0       2.0
# 3  0.071233          73.082783  46.018069    8.7    0.0       4.0
# 4  0.060274          72.531142  45.529238    8.7    0.0       4.0
# 6  0.093151          69.219446  47.671834    9.0    3.0       1.0
# 7  0.038356          72.991650  46.059594    8.8    0.0       3.0
#
# [5 rows x 33 columns]

# %%
col = df_total.columns.values

# %%
col
# Out:
# array(['fips', 'per_capita_income', 'percent_below_poverty',
#        'percent_no_highschool_diploma', 'percent_mobile_homes',
#        'percent_no_vehicle', 'percent_unemployed_CDC',
#        'percent_overcrowding', 'percent_multi_unit_housing',
#        'percent_age_65_and_older', 'percent_limited_english_abilities',
#        'percent_age_17_and_younger', 'percent_minorities',
#        'percent_disabled', 'percent_institutionalized_in_group_quarters',
#        'percent_single_parent_households_CDC', 'county',
#        'SuicideDeathRate', 'elevation', 'mean_temp', 'visibility',
#        'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail',
#        'thunder', 'Relative_Humidity', 'Heat_Index', 'PM2.5', 'Ozone',
#        'rurality'], dtype=object)

# %%
new_col = ['fips', 'county', 'percent_below_poverty',
       'per_capita_income', 'percent_unemployed_CDC',
       'percent_no_highschool_diploma', 'percent_age_65_and_older',
       'percent_age_17_and_younger', 'percent_disabled',
       'percent_single_parent_households_CDC', 'percent_minorities',
       'percent_limited_english_abilities', 'percent_multi_unit_housing',
       'percent_mobile_homes', 'percent_overcrowding',
       'percent_no_vehicle',
       'percent_institutionalized_in_group_quarters', 
       'elevation', 'mean_temp', 'visibility',
       'wind_speed', 'precipitation', 'Relative_Humidity', 'Heat_Index',
       'fog', 'rain', 'snow', 'hail', 'thunder', 'PM2.5',
       'Ozone', 'rurality','SuicideDeathRate']

# %%
df_total = df_total[new_col]

# %%
df_total.shape
# Out:
# (727, 33)

# %%
df_total.head()
# Out:
#     fips                  county  percent_below_poverty  per_capita_income  \
# 0  36119  Westchester County, NY               0.088929            48306.0
# 3  36109     Tompkins County, NY               0.203616            26199.0
# 4  36113       Warren County, NY               0.106980            28939.0
# 6  36055       Monroe County, NY               0.144338            27712.0
# 7  36065       Oneida County, NY               0.151475            24459.0
#
#    percent_unemployed_CDC  percent_no_highschool_diploma  \
# 0                0.189093                       0.131234
# 3                0.303702                       0.077040
# 4                0.195584                       0.098109
# 6                0.215928                       0.119694
# 7                0.226020                       0.143589
#
#    percent_age_65_and_older  percent_age_17_and_younger  percent_disabled  \
# 0                  0.145379                    0.241451          0.363424
# 3                  0.107064                    0.163372          0.383646
# 4                  0.167744                    0.207764          0.443926
# 6                  0.138034                    0.229035          0.417822
# 7                  0.161855                    0.219958          0.550351
#
#    percent_single_parent_households_CDC  ...  Heat_Index       fog      rain  \
# 0                              0.219030  ...   51.191235  0.172603  0.383562
# 3                              0.197805  ...   46.018069  0.164384  0.449315
# 4                              0.177804  ...   45.529238  0.268493  0.378082
# 6                              0.317078  ...   47.671834  0.095890  0.468493
# 7                              0.272954  ...   46.059594  0.200000  0.449315
#
#        snow     hail   thunder  PM2.5  Ozone  rurality  SuicideDeathRate
# 0  0.079452  0.00000  0.073973    9.4    5.0       2.0          4.498383
# 3  0.241096  0.00000  0.071233    8.7    0.0       4.0          9.830618
# 4  0.147945  0.00000  0.060274    8.7    0.0       4.0          7.696417
# 6  0.252055  0.00274  0.093151    9.0    3.0       1.0          6.303437
# 7  0.238356  0.00000  0.038356    8.8    0.0       3.0          4.695096
#
# [5 rows x 33 columns]

# %%
plt.rcParams.update({'figure.figsize': (20.0, 12.0)})
plt.rcParams.update({'font.size': 14})
X = df_total.iloc[:, 2:-1].values
y = df_total.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.02108446, 0.01761921, 0.02819011, 0.01422004, 0.05823231,
#        0.03618968, 0.04292327, 0.02245207, 0.11764606, 0.04220665,
#        0.02214921, 0.03888364, 0.01684297, 0.01900123, 0.01630411,
#        0.05688903, 0.02325533, 0.05232914, 0.02291092, 0.03416631,
#        0.01934902, 0.03912992, 0.01302831, 0.01488171, 0.01161687,
#        0.00266524, 0.03089226, 0.13764426, 0.02046608, 0.00683058])

# %%
len(rf.feature_importances_)
# Out:
# 30

# %%
columns = df_total.columns
columns = columns[2:-1]
columns = columns.tolist()
columns
# Out:
# ['percent_below_poverty',
#  'per_capita_income',
#  'percent_unemployed_CDC',
#  'percent_no_highschool_diploma',
#  'percent_age_65_and_older',
#  'percent_age_17_and_younger',
#  'percent_disabled',
#  'percent_single_parent_households_CDC',
#  'percent_minorities',
#  'percent_limited_english_abilities',
#  'percent_multi_unit_housing',
#  'percent_mobile_homes',
#  'percent_overcrowding',
#  'percent_no_vehicle',
#  'percent_institutionalized_in_group_quarters',
#  'elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'Relative_Humidity',
#  'Heat_Index',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'PM2.5',
#  'Ozone',
#  'rurality']

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %% [markdown]
# ## SHAP

# %%
import xgboost
import shap

# %%
X = climate_2011.iloc[:, 1:-1]
y = climate_2011.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"elevation"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"rurality"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"mean_temp"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:,"elevation"],shap_values[:,"rurality"], xmin=500)

# %%
shap.plots.scatter(shap_values[:, "PM2.5"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"PM2.5"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"PM2.5"])

# %%
shap.plots.scatter(shap_values[:, "PM2.5"], color=shap_values[:,"elevation"])

# %% [markdown]
# ### social economic factors

# %%
social_2011.head()
# Out:
#      fips  per_capita_income  percent_below_poverty  \
# 23  36119            48306.0               0.088929
# 26  36085            31276.0               0.110450
# 27  36089            21013.0               0.175920
# 28  36109            26199.0               0.203616
# 29  36113            28939.0               0.106980
#
#     percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 23                       0.131234              0.000916            0.144683
# 26                       0.131981              0.002494            0.159258
# 27                       0.139977              0.112157            0.080430
# 28                       0.077040              0.082709            0.136046
# 29                       0.098109              0.070767            0.067906
#
#     percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 23                0.189093              0.042072                    0.267763
# 26                0.233932              0.035518                    0.113446
# 27                0.297143              0.015374                    0.046975
# 28                0.303702              0.013444                    0.118258
# 29                0.195584              0.009439                    0.048014
#
#     percent_age_65_and_older  percent_limited_english_abilities  \
# 23                  0.145379                           0.306614
# 26                  0.125585                           0.290231
# 27                  0.136948                           0.053792
# 28                  0.107064                           0.137743
# 29                  0.167744                           0.048412
#
#     percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 23                    0.241451            0.418821          0.363424
# 26                    0.234017            0.352839          0.433010
# 27                    0.214857            0.071032          0.560817
# 28                    0.163372            0.199588          0.383646
# 29                    0.207764            0.046421          0.443926
#
#     percent_institutionalized_in_group_quarters  \
# 23                                     0.026259
# 26                                     0.021857
# 27                                     0.118354
# 28                                     0.133590
# 29                                     0.024739
#
#     percent_single_parent_households_CDC                   county  \
# 23                              0.219030   Westchester County, NY
# 26                              0.222412      Richmond County, NY
# 27                              0.227359  St. Lawrence County, NY
# 28                              0.197805      Tompkins County, NY
# 29                              0.177804        Warren County, NY
#
#     SuicideDeathRate
# 23          4.498383
# 26          3.613431
# 27          8.481045
# 28          9.830618
# 29          7.696417

# %%
X = social_2011.iloc[:, 1:-2]
y = social_2011.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"percent_mobile_homes"], color=shap_values)
