# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dask.dataframe as ddf
from pandas import Series, DataFrame
# %matplotlib inline

# %%
import seaborn as sn
import plotly.express as px

# %%
ur_files = ddf.read_csv('EnvironmentSuicide/Environment_Suicide_2017.csv', dtype = {'fips': str})
climate_2017 = ur_files.compute()
climate_2017 = climate_2017.loc[:, ~climate_2017.columns.str.contains('^Unnamed')]
climate_2017.head()
# Out:
#     fips   county   elevation  mean_temp  visibility  wind_speed  \
# 0  01001  Autauga   75.264706  66.432964    9.246260    3.987535
# 1  01003  Baldwin   12.427907  68.920833         NaN    5.980278
# 2  01005  Barbour   94.311111  67.550137    9.003976    3.042740
# 3  01007     Bibb  162.637500  65.090411    9.095616    3.364110
# 4  01009   Blount  243.931250  61.284658         NaN    3.994247
#
#    precipitation       fog      rain      snow  hail   thunder  \
# 0       0.196229  0.185596  0.520776  0.005540   0.0  0.135734
# 1       0.000000  0.000000  0.000000  0.000000   0.0  0.000000
# 2       0.165452  0.128767  0.383562  0.005479   0.0  0.186301
# 3       0.179808  0.126027  0.386301  0.010959   0.0  0.134247
# 4       0.166959  0.000000  0.000000  0.000000   0.0  0.000000
#
#    Relative_Humidity  Heat_Index  PM2.5  Ozone  rurality  SuicideDeathRate
# 0          72.545991   66.185922   10.0    0.0         3         21.620063
# 1                NaN         NaN    7.4    1.0         4         18.341893
# 2          70.541451   67.320599   10.2    0.0         6         19.283022
# 3          73.727778   64.764658    9.7    0.0         2         14.515451
# 4                NaN         NaN    9.8    0.0         2         18.961267

# %%
climate_2017 = climate_2017[['fips', 'elevation', 'mean_temp', 'visibility', 'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail', 'thunder', 'Relative_Humidity', 'Heat_Index', 'PM2.5', 'Ozone', 'rurality', 'SuicideDeathRate']]

# %%
climate_2017 = climate_2017.dropna()

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
import shap
from matplotlib import pyplot as plt

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
X = climate_2017.iloc[:, 1:-1].values
y = climate_2017.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.19283494, 0.05549449, 0.06058827, 0.06711376, 0.05086135,
#        0.0483471 , 0.07924747, 0.08291392, 0.00628948, 0.03749308,
#        0.06375718, 0.06924305, 0.07131431, 0.01317664, 0.10132495])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = climate_2017.columns

# %%
columns = columns[1:-1]
columns = columns.tolist()
columns
# Out:
# ['elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'Relative_Humidity',
#  'Heat_Index',
#  'PM2.5',
#  'Ozone',
#  'rurality']

# %%
len(columns)
# Out:
# 15

# %%
plt.barh(columns, rf.feature_importances_)
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
sorted_idx
# Out:
# array([ 8, 13,  9,  5,  4,  1,  2, 10,  3, 11, 12,  6,  7, 14,  0])

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
rf.feature_importances_[sorted_idx]
# Out:
# array([0.00628948, 0.01317664, 0.03749308, 0.0483471 , 0.05086135,
#        0.05549449, 0.06058827, 0.06375718, 0.06711376, 0.06924305,
#        0.07131431, 0.07924747, 0.08291392, 0.10132495, 0.19283494])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
def correlation_matrix(df):
    """
    A function to calculate and plot
    correlation matrix of a DataFrame.
    """
    # Create the matrix
    matrix = df.corr()
    
    # Create cmap
    cmap = sn.diverging_palette(250, 15, s=75, l=40,
                             n=9, center="light", as_cmap=True)
    # Create a mask
    mask = np.triu(np.ones_like(matrix, dtype=bool))
    
    # Make figsize bigger
    fig, ax = plt.subplots(figsize=(16,12))
    
    # Plot the matrix
    _ = sn.heatmap(matrix, mask=mask, center=0, annot=True,
             fmt='.2f', square=True, cmap=cmap, ax=ax)

# %%
correlation_matrix(climate_2017)

# %% [markdown]
# ## Find the economic feature importances

# %%
ur_files = ddf.read_csv('SocialEconomicSuicide/Social_Economic_Suicide_2017.csv', dtype = {'fips': str, 'per_capita_income': float})
social_2017 = ur_files.compute()
social_2017 = social_2017.loc[:, ~social_2017.columns.str.contains('^Unnamed')]
social_2017.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  40045            27272.0               0.171555
# 1  40051            27334.0               0.124159
# 2  40119            22785.0               0.263145
# 3  40125            22284.0               0.169700
# 4  40037            24056.0               0.151820
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.124121              0.141763            0.028923
# 1                       0.119022              0.145647            0.033480
# 2                       0.089728              0.100425            0.056900
# 3                       0.135085              0.122731            0.052806
# 4                       0.137377              0.208241            0.036480
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.225352              0.010462                    0.005712
# 1                0.208998              0.021679                    0.023391
# 2                0.321887              0.033154                    0.111002
# 3                0.243826              0.024648                    0.032731
# 4                0.227509              0.035571                    0.024049
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.209410                           0.045809
# 1                  0.151570                           0.037375
# 2                  0.116006                           0.062704
# 3                  0.155835                           0.043118
# 4                  0.167859                           0.026556
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.236714            0.130912          0.481632
# 1                    0.244448            0.180015          0.617015
# 2                    0.193678            0.226592          0.529113
# 3                    0.243011            0.270296          0.647418
# 4                    0.242246            0.232415          0.494830
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.012921
# 1                                     0.012640
# 2                                     0.099003
# 3                                     0.045424
# 4                                     0.011721
#
#    percent_single_parent_households_CDC                   county  \
# 0                              0.285273         Ellis County, OK
# 1                              0.219735         Grady County, OK
# 2                              0.218812         Payne County, OK
# 3                              0.256268  Pottawatomie County, OK
# 4                              0.262649         Creek County, OK
#
#    SuicideDeathRate
# 0         22.410690
# 1         22.775042
# 2         14.710389
# 3         16.614516
# 4         13.946223

# %%
social_2017['SuicideDeathRate'].isna().sum()
# Out:
# 87

# %%
plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 14})
social_2017 = social_2017.dropna(how = 'any')

# %%
social_2017.shape
# Out:
# (3131, 18)

# %%
X = social_2017.iloc[:, 1:-2].values
y = social_2017.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.04163206, 0.04007663, 0.06012175, 0.14214718, 0.04719789,
#        0.05020974, 0.12124154, 0.04138158, 0.12265138, 0.05937184,
#        0.04465205, 0.06108104, 0.07614059, 0.04006969, 0.05202504])

# %%
len(rf.feature_importances_)
# Out:
# 15

# %%
columns = social_2017.columns
columns = columns[1:-2]
columns = columns.tolist()
columns
# Out:
# ['per_capita_income',
#  'percent_below_poverty',
#  'percent_no_highschool_diploma',
#  'percent_mobile_homes',
#  'percent_no_vehicle',
#  'percent_unemployed_CDC',
#  'percent_overcrowding',
#  'percent_multi_unit_housing',
#  'percent_age_65_and_older',
#  'percent_limited_english_abilities',
#  'percent_age_17_and_younger',
#  'percent_minorities',
#  'percent_disabled',
#  'percent_institutionalized_in_group_quarters',
#  'percent_single_parent_households_CDC']

# %%
social_2017.shape
# Out:
# (3131, 18)

# %%
climate_2017.shape
# Out:
# (2788, 17)

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %%
correlation_matrix(social_2017)

# %% [markdown]
# ## find the rank of importances of all factors

# %%
df_total = social_2017.merge(climate_2017, on = ['fips', 'SuicideDeathRate'], how = 'left')
df_total = df_total.dropna(how = 'any')
df_total.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  40045            27272.0               0.171555
# 1  40051            27334.0               0.124159
# 3  40125            22284.0               0.169700
# 4  40037            24056.0               0.151820
# 5  40141            21422.0               0.221086
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.124121              0.141763            0.028923
# 1                       0.119022              0.145647            0.033480
# 3                       0.135085              0.122731            0.052806
# 4                       0.137377              0.208241            0.036480
# 5                       0.249565              0.042624            0.060093
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.225352              0.010462                    0.005712
# 1                0.208998              0.021679                    0.023391
# 3                0.243826              0.024648                    0.032731
# 4                0.227509              0.035571                    0.024049
# 5                0.229356              0.040837                    0.013951
#
#    percent_age_65_and_older  ...       fog      rain      snow  hail  \
# 0                  0.209410  ...  0.057534  0.265753  0.024658   0.0
# 1                  0.151570  ...  0.022039  0.126722  0.013774   0.0
# 3                  0.155835  ...  0.049451  0.255495  0.019231   0.0
# 4                  0.167859  ...  0.043836  0.284932  0.016438   0.0
# 5                  0.191543  ...  0.071429  0.241758  0.016484   0.0
#
#     thunder  Relative_Humidity Heat_Index  PM2.5  Ozone  rurality
# 0  0.095890          54.332139  58.003474    6.7    0.0       6.0
# 1  0.052342          64.750792  60.854196    8.4    1.0       2.0
# 3  0.123626          63.572170  60.514980    8.8    0.0       5.0
# 4  0.136986          58.682778  63.261022   10.0    0.0       3.0
# 5  0.104396          58.634152  62.970036    7.6    0.0       6.0
#
# [5 rows x 33 columns]

# %%
col = df_total.columns.values

# %%
col
# Out:
# array(['fips', 'per_capita_income', 'percent_below_poverty',
#        'percent_no_highschool_diploma', 'percent_mobile_homes',
#        'percent_no_vehicle', 'percent_unemployed_CDC',
#        'percent_overcrowding', 'percent_multi_unit_housing',
#        'percent_age_65_and_older', 'percent_limited_english_abilities',
#        'percent_age_17_and_younger', 'percent_minorities',
#        'percent_disabled', 'percent_institutionalized_in_group_quarters',
#        'percent_single_parent_households_CDC', 'county',
#        'SuicideDeathRate', 'elevation', 'mean_temp', 'visibility',
#        'wind_speed', 'precipitation', 'fog', 'rain', 'snow', 'hail',
#        'thunder', 'Relative_Humidity', 'Heat_Index', 'PM2.5', 'Ozone',
#        'rurality'], dtype=object)

# %%
new_col = ['fips', 'county', 'percent_below_poverty',
       'per_capita_income', 'percent_unemployed_CDC',
       'percent_no_highschool_diploma', 'percent_age_65_and_older',
       'percent_age_17_and_younger', 'percent_disabled',
       'percent_single_parent_households_CDC', 'percent_minorities',
       'percent_limited_english_abilities', 'percent_multi_unit_housing',
       'percent_mobile_homes', 'percent_overcrowding',
       'percent_no_vehicle',
       'percent_institutionalized_in_group_quarters', 
       'elevation', 'mean_temp', 'visibility',
       'wind_speed', 'precipitation', 'Relative_Humidity', 'Heat_Index',
       'fog', 'rain', 'snow', 'hail', 'thunder', 'PM2.5',
       'Ozone', 'rurality','SuicideDeathRate']

# %%
df_total = df_total[new_col]

# %%
df_total.shape
# Out:
# (2787, 33)

# %%
df_total.head()
# Out:
#     fips                   county  percent_below_poverty  per_capita_income  \
# 0  40045         Ellis County, OK               0.171555            27272.0
# 1  40051         Grady County, OK               0.124159            27334.0
# 3  40125  Pottawatomie County, OK               0.169700            22284.0
# 4  40037         Creek County, OK               0.151820            24056.0
# 5  40141       Tillman County, OK               0.221086            21422.0
#
#    percent_unemployed_CDC  percent_no_highschool_diploma  \
# 0                0.225352                       0.124121
# 1                0.208998                       0.119022
# 3                0.243826                       0.135085
# 4                0.227509                       0.137377
# 5                0.229356                       0.249565
#
#    percent_age_65_and_older  percent_age_17_and_younger  percent_disabled  \
# 0                  0.209410                    0.236714          0.481632
# 1                  0.151570                    0.244448          0.617015
# 3                  0.155835                    0.243011          0.647418
# 4                  0.167859                    0.242246          0.494830
# 5                  0.191543                    0.241734          0.548624
#
#    percent_single_parent_households_CDC  ...  Heat_Index       fog      rain  \
# 0                              0.285273  ...   58.003474  0.057534  0.265753
# 1                              0.219735  ...   60.854196  0.022039  0.126722
# 3                              0.256268  ...   60.514980  0.049451  0.255495
# 4                              0.262649  ...   63.261022  0.043836  0.284932
# 5                              0.304090  ...   62.970036  0.071429  0.241758
#
#        snow  hail   thunder  PM2.5  Ozone  rurality  SuicideDeathRate
# 0  0.024658   0.0  0.095890    6.7    0.0       6.0         22.410690
# 1  0.013774   0.0  0.052342    8.4    1.0       2.0         22.775042
# 3  0.019231   0.0  0.123626    8.8    0.0       5.0         16.614516
# 4  0.016438   0.0  0.136986   10.0    0.0       3.0         13.946223
# 5  0.016484   0.0  0.104396    7.6    0.0       6.0         21.584208
#
# [5 rows x 33 columns]

# %%
plt.rcParams.update({'figure.figsize': (20.0, 12.0)})
plt.rcParams.update({'font.size': 14})
X = df_total.iloc[:, 2:-1].values
y = df_total.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=12)

# %%
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)
rf.feature_importances_
# Out:
# array([0.01920528, 0.02310929, 0.0259827 , 0.01841964, 0.06870871,
#        0.01957766, 0.05255261, 0.02052515, 0.05702155, 0.03870349,
#        0.01884952, 0.12417216, 0.01885004, 0.02456462, 0.02012739,
#        0.13913183, 0.01714257, 0.03273666, 0.02024766, 0.02079392,
#        0.02602892, 0.02361636, 0.01683867, 0.02744151, 0.05420129,
#        0.00154864, 0.01760915, 0.02479177, 0.00243595, 0.02506529])

# %%
len(rf.feature_importances_)
# Out:
# 30

# %%
columns = df_total.columns
columns = columns[2:-1]
columns = columns.tolist()
columns
# Out:
# ['percent_below_poverty',
#  'per_capita_income',
#  'percent_unemployed_CDC',
#  'percent_no_highschool_diploma',
#  'percent_age_65_and_older',
#  'percent_age_17_and_younger',
#  'percent_disabled',
#  'percent_single_parent_households_CDC',
#  'percent_minorities',
#  'percent_limited_english_abilities',
#  'percent_multi_unit_housing',
#  'percent_mobile_homes',
#  'percent_overcrowding',
#  'percent_no_vehicle',
#  'percent_institutionalized_in_group_quarters',
#  'elevation',
#  'mean_temp',
#  'visibility',
#  'wind_speed',
#  'precipitation',
#  'Relative_Humidity',
#  'Heat_Index',
#  'fog',
#  'rain',
#  'snow',
#  'hail',
#  'thunder',
#  'PM2.5',
#  'Ozone',
#  'rurality']

# %%
sorted_idx = rf.feature_importances_.argsort()

# %%
columns_sorted = []
for index in sorted_idx:
    columns_sorted.append(columns[index])

# %%
plt.barh(columns_sorted, rf.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')

# %% [markdown]
# ## SHAP

# %%
import xgboost
import shap

# %%
X = climate_2017.iloc[:, 1:-1]
y = climate_2017.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"elevation"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:,"rurality"], color=shap_values)

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:, "PM2.5"], color=shap_values[:,"rurality"])

# %%
shap.plots.scatter(shap_values[:, "rurality"], color=shap_values[:,"PM2.5"])

# %%
shap.plots.scatter(shap_values[:, "PM2.5"], color=shap_values[:,"elevation"])

# %%
shap.plots.scatter(shap_values[:, "elevation"], color=shap_values[:,"PM2.5"])

# %% [markdown]
# ### Social economic factors

# %%
social_2017.head()
# Out:
#     fips  per_capita_income  percent_below_poverty  \
# 0  40045            27272.0               0.171555
# 1  40051            27334.0               0.124159
# 2  40119            22785.0               0.263145
# 3  40125            22284.0               0.169700
# 4  40037            24056.0               0.151820
#
#    percent_no_highschool_diploma  percent_mobile_homes  percent_no_vehicle  \
# 0                       0.124121              0.141763            0.028923
# 1                       0.119022              0.145647            0.033480
# 2                       0.089728              0.100425            0.056900
# 3                       0.135085              0.122731            0.052806
# 4                       0.137377              0.208241            0.036480
#
#    percent_unemployed_CDC  percent_overcrowding  percent_multi_unit_housing  \
# 0                0.225352              0.010462                    0.005712
# 1                0.208998              0.021679                    0.023391
# 2                0.321887              0.033154                    0.111002
# 3                0.243826              0.024648                    0.032731
# 4                0.227509              0.035571                    0.024049
#
#    percent_age_65_and_older  percent_limited_english_abilities  \
# 0                  0.209410                           0.045809
# 1                  0.151570                           0.037375
# 2                  0.116006                           0.062704
# 3                  0.155835                           0.043118
# 4                  0.167859                           0.026556
#
#    percent_age_17_and_younger  percent_minorities  percent_disabled  \
# 0                    0.236714            0.130912          0.481632
# 1                    0.244448            0.180015          0.617015
# 2                    0.193678            0.226592          0.529113
# 3                    0.243011            0.270296          0.647418
# 4                    0.242246            0.232415          0.494830
#
#    percent_institutionalized_in_group_quarters  \
# 0                                     0.012921
# 1                                     0.012640
# 2                                     0.099003
# 3                                     0.045424
# 4                                     0.011721
#
#    percent_single_parent_households_CDC                   county  \
# 0                              0.285273         Ellis County, OK
# 1                              0.219735         Grady County, OK
# 2                              0.218812         Payne County, OK
# 3                              0.256268  Pottawatomie County, OK
# 4                              0.262649         Creek County, OK
#
#    SuicideDeathRate
# 0         22.410690
# 1         22.775042
# 2         14.710389
# 3         16.614516
# 4         13.946223

# %%
X = social_2017.iloc[:, 1:-2]
y = social_2017.iloc[:, -1].array

# %%
model = xgboost.XGBRegressor().fit(X, y)

# %%
# explain the model's predictions using SHAP
# (same syntax works for LightGBM, CatBoost, scikit-learn, transformers, Spark, etc.)
explainer = shap.Explainer(model)
shap_values = explainer(X)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)

# %%
shap.plots.scatter(shap_values[:,"percent_mobile_homes"], color=shap_values)
